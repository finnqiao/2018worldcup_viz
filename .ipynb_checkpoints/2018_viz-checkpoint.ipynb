# %%
import json
import pandas as pd
import seaborn as sb
import matplotlib
import matplotlib.pyplot as plt
import numpy as np
from pandas.io.json import json_normalize

# %%
with open('worldcup.teams.json') as f:
    d = json.load(f)
    
teams_df = json_normalize(d['teams'])
teams_df = teams_df[['code','continent','name']]
teams_df.columns = ['countrycode','continent','scorer_team']
teams_df.head()
# Out:
#   countrycode continent scorer_team
# 0         EGY    Africa       Egypt
# 1         MAR    Africa     Morocco
# 2         TUN    Africa     Tunisia
# 3         SEN    Africa     Senegal
# 4         NGA    Africa     Nigeria

# %%
teams = teams_df['scorer_team'].unique()
teams
# Out:
# array(['Egypt', 'Morocco', 'Tunisia', 'Senegal', 'Nigeria', 'Japan',
#        'South Korea', 'Costa Rica', 'Panama', 'Belgium', 'Germany',
#        'Spain', 'France', 'Portugal', 'Denmark', 'Poland', 'Sweden',
#        'Switzerland', 'Croatia', 'Serbia', 'Russia', 'Iceland', 'England',
#        'Iran', 'Saudi Arabia', 'Mexico', 'Australia', 'Argentina',
#        'Brazil', 'Uruguay', 'Colombia', 'Peru'], dtype=object)

# %%
with open('worldcup.json') as f:
    d = json.load(f)
    
games_df = json_normalize(data = d['rounds'], record_path = 'matches')
games_df
# Out:
#                 city        date  \
# 0             Moscow  2018-06-14
# 1       Ekaterinburg  2018-06-15
# 2              Sochi  2018-06-15
# 3   Saint Petersburg  2018-06-15
# 4              Kazan  2018-06-16
# 5            Saransk  2018-06-16
# 6             Moscow  2018-06-16
# 7        Kaliningrad  2018-06-16
# 8      Rostov-on-Don  2018-06-17
# 9             Samara  2018-06-17
# 10            Moscow  2018-06-17
# 11   Nizhny Novgorod  2018-06-18
# 12             Sochi  2018-06-18
# 13         Volgograd  2018-06-18
# 14            Moscow  2018-06-19
# 15           Saransk  2018-06-19
# 16  Saint Petersburg  2018-06-19
# 17     Rostov-on-Don  2018-06-20
# 18            Moscow  2018-06-20
# 19             Kazan  2018-06-20
# 20      Ekaterinburg  2018-06-21
# 21            Samara  2018-06-21
# 22   Nizhny Novgorod  2018-06-21
# 23         Volgograd  2018-06-22
# 24  Saint Petersburg  2018-06-22
# 25       Kaliningrad  2018-06-22
# 26             Sochi  2018-06-23
# 27     Rostov-on-Don  2018-06-23
# 28            Moscow  2018-06-23
# 29   Nizhny Novgorod  2018-06-24
# ..               ...         ...
# 34           Saransk  2018-06-25
# 35       Kaliningrad  2018-06-25
# 36            Moscow  2018-06-26
# 37             Sochi  2018-06-26
# 38  Saint Petersburg  2018-06-26
# 39     Rostov-on-Don  2018-06-26
# 40            Moscow  2018-06-27
# 41   Nizhny Novgorod  2018-06-27
# 42             Kazan  2018-06-27
# 43      Ekaterinburg  2018-06-27
# 44       Kaliningrad  2018-06-28
# 45           Saransk  2018-06-28
# 46         Volgograd  2018-06-28
# 47            Samara  2018-06-28
# 48             Sochi  2018-06-30
# 49             Kazan  2018-06-30
# 50            Moscow  2018-07-01
# 51   Nizhny Novgorod  2018-07-01
# 52            Samara  2018-07-02
# 53     Rostov-on-Don  2018-07-02
# 54  Saint Petersburg  2018-07-03
# 55            Moscow  2018-07-03
# 56   Nizhny Novgorod  2018-07-06
# 57             Kazan  2018-07-06
# 58             Sochi  2018-07-07
# 59            Samara  2018-07-07
# 60  Saint Petersburg  2018-07-10
# 61            Moscow  2018-07-11
# 62  Saint Petersburg  2018-07-14
# 63            Moscow  2018-07-15
#
#                                                goals1  \
# 0   [{'name': 'Gazinsky', 'minute': 12, 'score1': ...
# 1                                                  []
# 2   [{'name': 'Ronaldo', 'minute': 4, 'score1': 1,...
# 3                                                  []
# 4   [{'name': 'Griezmann', 'minute': 58, 'score1':...
# 5                                                  []
# 6   [{'name': 'Agüero', 'minute': 19, 'score1': 1,...
# 7   [{'name': 'Etebo', 'minute': 32, 'score1': 1, ...
# 8   [{'name': 'Coutinho', 'minute': 20, 'score1': ...
# 9                                                  []
# 10                                                 []
# 11  [{'name': 'Granqvist', 'minute': 65, 'score1':...
# 12  [{'name': 'Mertens', 'minute': 47, 'score1': 1...
# 13  [{'name': 'Sassi', 'minute': 35, 'score1': 1, ...
# 14  [{'name': 'Krychowiak', 'minute': 86, 'score1'...
# 15  [{'name': 'J. Quintero', 'minute': 39, 'score1...
# 16  [{'name': 'A. Fathi', 'minute': 47, 'score1': ...
# 17  [{'name': 'L. Suárez', 'minute': 23, 'score1':...
# 18  [{'name': 'Ronaldo', 'minute': 4, 'score1': 1,...
# 19                                                 []
# 20  [{'name': 'Mbappé', 'minute': 34, 'score1': 1,...
# 21  [{'name': 'Eriksen', 'minute': 7, 'score1': 1,...
# 22                                                 []
# 23  [{'name': 'Musa', 'minute': 49, 'score1': 1, '...
# 24                                                NaN
# 25  [{'name': 'Mitrović', 'minute': 5, 'score1': 1...
# 26  [{'name': 'Reus', 'minute': 48, 'score1': 1, '...
# 27  [{'name': 'Son Heung-min', 'minute': 90, 'offs...
# 28  [{'name': 'E. Hazard', 'minute': 6, 'score1': ...
# 29  [{'name': 'Stones', 'minute': 8, 'score1': 1, ...
# ..                                                ...
# 34  [{'name': 'Karim Ansarifard', 'minute': 90, 'o...
# 35  [{'name': 'Isco', 'minute': 19, 'score1': 1, '...
# 36                                                NaN
# 37                                                 []
# 38  [{'name': 'Moses', 'minute': 51, 'score1': 1, ...
# 39  [{'name': 'G. Sigurðsson', 'minute': 76, 'scor...
# 40                                                 []
# 41  [{'name': 'Džemaili', 'minute': 31, 'score1': ...
# 42  [{'name': 'Kim Young-gwon', 'minute': 90, 'off...
# 43                                                 []
# 44                                                 []
# 45  [{'name': 'Yassine Meriah', 'minute': 33, 'sco...
# 46                                                 []
# 47                                                 []
# 48  [{'name': 'Edinson Cavani', 'minute': 7, 'scor...
# 49  [{'name': 'Antoine Griezmann', 'minute': 13, '...
# 50  [{'name': 'Sergei Ignashevich', 'minute': 12, ...
# 51  [{'name': 'Mario Mandžukić', 'minute': 4, 'sco...
# 52  [{'name': 'Neymar', 'minute': 51, 'score1': 1,...
# 53  [{'name': 'Jan Vertonghen', 'minute': 69, 'sco...
# 54  [{'name': 'Emil Forsberg', 'minute': 66, 'scor...
# 55  [{'name': 'Yerry Mina', 'minute': 90, 'offset'...
# 56                                                 []
# 57  [{'name': 'Renato Augusto', 'minute': 76, 'sco...
# 58  [{'name': 'Denis Cheryshev', 'minute': 31, 'sc...
# 59                                                 []
# 60  [{'name': 'Samuel Umtiti', 'minute': 51, 'scor...
# 61  [{'name': 'Ivan Perišić', 'minute': 68, 'score...
# 62  [{'name': 'Thomas Meunier', 'minute': 4, 'scor...
# 63  [{'name': 'Mario Mandžukić', 'minute': 18, 'sc...
#
#                                                goals2    group knockout  num  \
# 0                                                  []  Group A      NaN    1
# 1   [{'name': 'Giménez', 'minute': 89, 'score1': 0...  Group A      NaN    2
# 2   [{'name': 'Costa', 'minute': 24, 'score1': 1, ...  Group B      NaN    3
# 3   [{'name': 'Bouhaddouz', 'minute': 90, 'offset'...  Group B      NaN    4
# 4   [{'name': 'Jedinak', 'minute': 62, 'score1': 1...  Group C      NaN    5
# 5   [{'name': 'Poulsen', 'minute': 59, 'score1': 0...  Group C      NaN    6
# 6   [{'name': 'Finnbogason', 'minute': 23, 'score1...  Group D      NaN    7
# 7                                                  []  Group D      NaN    8
# 8   [{'name': 'Zuber', 'minute': 50, 'score1': 1, ...  Group E      NaN    9
# 9   [{'name': 'Kolarov', 'minute': 56, 'score1': 0...  Group E      NaN   10
# 10  [{'name': 'Lozano', 'minute': 35, 'score1': 0,...  Group F      NaN   11
# 11                                                 []  Group F      NaN   12
# 12                                                 []  Group G      NaN   13
# 13  [{'name': 'Kane', 'minute': 11, 'score1': 0, '...  Group G      NaN   14
# 14  [{'name': 'Cionek', 'minute': 37, 'score1': 0,...  Group H      NaN   15
# 15  [{'name': 'Kagawa', 'minute': 6, 'score1': 0, ...  Group H      NaN   16
# 16  [{'name': 'M. Salah', 'minute': 73, 'score1': ...  Group A      NaN   17
# 17                                                 []  Group A      NaN   18
# 18                                                 []  Group B      NaN   19
# 19  [{'name': 'Diego Costa', 'minute': 54, 'score1...  Group B      NaN   20
# 20                                                 []  Group C      NaN   21
# 21  [{'name': 'Jedinak', 'minute': 38, 'score1': 1...  Group C      NaN   22
# 22  [{'name': 'Rebić', 'minute': 53, 'score1': 0, ...  Group D      NaN   23
# 23                                                 []  Group D      NaN   24
# 24                                                NaN  Group E      NaN   25
# 25  [{'name': 'Xhaka', 'minute': 52, 'score1': 1, ...  Group E      NaN   26
# 26  [{'name': 'Toivonen', 'minute': 32, 'score1': ...  Group F      NaN   27
# 27  [{'name': 'Carlos V.', 'minute': 26, 'score1':...  Group F      NaN   28
# 28  [{'name': 'Bronn', 'minute': 18, 'score1': 2, ...  Group G      NaN   29
# 29  [{'name': 'Baloy', 'minute': 78, 'score1': 6, ...  Group G      NaN   30
# ..                                                ...      ...      ...  ...
# 34  [{'name': 'Quaresma', 'minute': 45, 'score1': ...  Group B      NaN   35
# 35  [{'name': 'Boutaib', 'minute': 14, 'score1': 0...  Group B      NaN   36
# 36                                                NaN  Group C      NaN   37
# 37  [{'name': 'Carrillo', 'minute': 18, 'score1': ...  Group C      NaN   38
# 38  [{'name': 'Messi', 'minute': 14, 'score1': 0, ...  Group D      NaN   39
# 39  [{'name': 'Badelj', 'minute': 53, 'score1': 0,...  Group D      NaN   40
# 40  [{'name': 'Paulinho', 'minute': 36, 'score1': ...  Group E      NaN   41
# 41  [{'name': 'Waston', 'minute': 56, 'score1': 1,...  Group E      NaN   42
# 42                                                 []  Group F      NaN   43
# 43  [{'name': 'Augustinsson', 'minute': 50, 'score...  Group F      NaN   44
# 44  [{'name': 'Adnan Januzaj', 'minute': 51, 'scor...  Group G      NaN   45
# 45  [{'name': 'Fakhereedine Ben Youssef', 'minute'...  Group G      NaN   46
# 46  [{'name': 'Bednarek', 'minute': 59, 'score1': ...  Group H      NaN   47
# 47  [{'name': 'Y. Mina', 'minute': 74, 'score1': 0...  Group H      NaN   48
# 48  [{'name': 'Pepe', 'minute': 55, 'score1': 1, '...      NaN     True   49
# 49  [{'name': 'Ángel Di María', 'minute': 41, 'sco...      NaN     True   50
# 50  [{'name': 'Artem Dzyuba', 'minute': 41, 'score...      NaN     True   51
# 51  [{'name': 'Mathias Jørgensen', 'minute': 1, 's...      NaN     True   52
# 52                                                 []      NaN     True   53
# 53  [{'name': 'Genki Haraguchi', 'minute': 48, 'sc...      NaN     True   54
# 54                                                 []      NaN     True   55
# 55  [{'name': 'Harry Kane', 'minute': 57, 'score1'...      NaN     True   56
# 56  [{'name': 'Raphaël Varane', 'minute': 40, 'sco...      NaN     True   57
# 57  [{'name': 'Fernandinho', 'minute': 13, 'score1...      NaN     True   58
# 58  [{'name': 'Andrej Kramarić', 'minute': 39, 'sc...      NaN     True   59
# 59  [{'name': 'Harry Maguire', 'minute': 30, 'scor...      NaN     True   60
# 60                                                 []      NaN     True   61
# 61  [{'name': 'Kieran Trippier', 'minute': 5, 'sco...      NaN     True   62
# 62                                                 []      NaN     True   63
# 63  [{'name': 'Perišić', 'minute': 28, 'score1': 1...      NaN     True   64
#
#     score1  score1et  score1i  score1p  score2  score2et  score2i  score2p  \
# 0        5       NaN        2      NaN       0       NaN        0      NaN
# 1        0       NaN        0      NaN       1       NaN        0      NaN
# 2        3       NaN        2      NaN       3       NaN        1      NaN
# 3        0       NaN        0      NaN       1       NaN        0      NaN
# 4        2       NaN        0      NaN       1       NaN        0      NaN
# 5        0       NaN        0      NaN       1       NaN        0      NaN
# 6        1       NaN        1      NaN       1       NaN        1      NaN
# 7        2       NaN        1      NaN       0       NaN        0      NaN
# 8        1       NaN        1      NaN       1       NaN        0      NaN
# 9        0       NaN        0      NaN       1       NaN        0      NaN
# 10       0       NaN        0      NaN       1       NaN        1      NaN
# 11       1       NaN        0      NaN       0       NaN        0      NaN
# 12       3       NaN        0      NaN       0       NaN        0      NaN
# 13       1       NaN        1      NaN       2       NaN        1      NaN
# 14       1       NaN        0      NaN       2       NaN        1      NaN
# 15       1       NaN        1      NaN       2       NaN        1      NaN
# 16       3       NaN        0      NaN       1       NaN        0      NaN
# 17       1       NaN        1      NaN       0       NaN        0      NaN
# 18       1       NaN        1      NaN       0       NaN        0      NaN
# 19       0       NaN        0      NaN       1       NaN        0      NaN
# 20       1       NaN        1      NaN       0       NaN        0      NaN
# 21       1       NaN        1      NaN       1       NaN        1      NaN
# 22       0       NaN        0      NaN       3       NaN        0      NaN
# 23       2       NaN        0      NaN       0       NaN        0      NaN
# 24       2       NaN        0      NaN       0       NaN        0      NaN
# 25       1       NaN        1      NaN       2       NaN        0      NaN
# 26       2       NaN        0      NaN       1       NaN        1      NaN
# 27       1       NaN        0      NaN       2       NaN        1      NaN
# 28       5       NaN        3      NaN       2       NaN        1      NaN
# 29       6       NaN        5      NaN       1       NaN        0      NaN
# ..     ...       ...      ...      ...     ...       ...      ...      ...
# 34       1       NaN        0      NaN       1       NaN        1      NaN
# 35       2       NaN        1      NaN       2       NaN        1      NaN
# 36       0       NaN        0      NaN       0       NaN        0      NaN
# 37       0       NaN        0      NaN       2       NaN        1      NaN
# 38       1       NaN        0      NaN       2       NaN        1      NaN
# 39       1       NaN        0      NaN       2       NaN        0      NaN
# 40       0       NaN        0      NaN       2       NaN        1      NaN
# 41       2       NaN        1      NaN       2       NaN        0      NaN
# 42       2       NaN        0      NaN       0       NaN        0      NaN
# 43       0       NaN        0      NaN       3       NaN        0      NaN
# 44       0       NaN        0      NaN       1       NaN        0      NaN
# 45       1       NaN        1      NaN       2       NaN        0      NaN
# 46       0       NaN        0      NaN       1       NaN        1      NaN
# 47       0       NaN        0      NaN       1       NaN        1      NaN
# 48       2       NaN        1      NaN       1       NaN        0      NaN
# 49       4       NaN        1      NaN       3       NaN        1      NaN
# 50       1       1.0        1      3.0       1       1.0        1      4.0
# 51       1       1.0        1      3.0       1       1.0        1      2.0
# 52       2       NaN        0      NaN       0       NaN        0      NaN
# 53       3       NaN        0      NaN       2       NaN        0      NaN
# 54       1       NaN        0      NaN       0       NaN        0      NaN
# 55       1       1.0        0      3.0       1       1.0        0      4.0
# 56       0       NaN        0      NaN       2       NaN        1      NaN
# 57       1       NaN        0      NaN       2       NaN        2      NaN
# 58       1       2.0        1      3.0       1       2.0        1      4.0
# 59       0       NaN        0      NaN       2       NaN        1      NaN
# 60       1       NaN        0      NaN       0       NaN        0      NaN
# 61       1       2.0        0      NaN       1       1.0        1      NaN
# 62       2       NaN        1      NaN       0       NaN        0      NaN
# 63       4       NaN        2      NaN       2       NaN        1      NaN
#
#                                               stadium  \
# 0     {'key': 'luzhniki', 'name': 'Luzhniki Stadium'}
# 1   {'key': 'ekaterinburg', 'name': 'Ekaterinburg ...
# 2           {'key': 'fisht', 'name': 'Fisht Stadium'}
# 3   {'key': 'saintpetersburg', 'name': 'Saint Pete...
# 4             {'key': 'kazan', 'name': 'Kazan Arena'}
# 5       {'key': 'mordovia', 'name': 'Mordovia Arena'}
# 6       {'key': 'spartak', 'name': 'Spartak Stadium'}
# 7   {'key': 'kaliningrad', 'name': 'Kaliningrad St...
# 8           {'key': 'rostov', 'name': 'Rostov Arena'}
# 9           {'key': 'samara', 'name': 'Samara Arena'}
# 10    {'key': 'luzhniki', 'name': 'Luzhniki Stadium'}
# 11  {'key': 'nizhnynovgorod', 'name': 'Nizhny Novg...
# 12          {'key': 'fisht', 'name': 'Fisht Stadium'}
# 13    {'key': 'volgograd', 'name': 'Volgograd Arena'}
# 14      {'key': 'spartak', 'name': 'Spartak Stadium'}
# 15      {'key': 'mordovia', 'name': 'Mordovia Arena'}
# 16  {'key': 'saintpetersburg', 'name': 'Saint Pete...
# 17          {'key': 'rostov', 'name': 'Rostov Arena'}
# 18    {'key': 'luzhniki', 'name': 'Luzhniki Stadium'}
# 19            {'key': 'kazan', 'name': 'Kazan Arena'}
# 20  {'key': 'ekaterinburg', 'name': 'Ekaterinburg ...
# 21          {'key': 'samara', 'name': 'Samara Arena'}
# 22  {'key': 'nizhnynovgorod', 'name': 'Nizhny Novg...
# 23    {'key': 'volgograd', 'name': 'Volgograd Arena'}
# 24  {'key': 'saintpetersburg', 'name': 'Saint Pete...
# 25  {'key': 'kaliningrad', 'name': 'Kaliningrad St...
# 26          {'key': 'fisht', 'name': 'Fisht Stadium'}
# 27          {'key': 'rostov', 'name': 'Rostov Arena'}
# 28      {'key': 'spartak', 'name': 'Spartak Stadium'}
# 29  {'key': 'nizhnynovgorod', 'name': 'Nizhny Novg...
# ..                                                ...
# 34      {'key': 'mordovia', 'name': 'Mordovia Arena'}
# 35  {'key': 'kaliningrad', 'name': 'Kaliningrad St...
# 36    {'key': 'luzhniki', 'name': 'Luzhniki Stadium'}
# 37          {'key': 'fisht', 'name': 'Fisht Stadium'}
# 38  {'key': 'saintpetersburg', 'name': 'Saint Pete...
# 39          {'key': 'rostov', 'name': 'Rostov Arena'}
# 40      {'key': 'spartak', 'name': 'Spartak Stadium'}
# 41  {'key': 'nizhnynovgorod', 'name': 'Nizhny Novg...
# 42            {'key': 'kazan', 'name': 'Kazan Arena'}
# 43  {'key': 'ekaterinburg', 'name': 'Ekaterinburg ...
# 44  {'key': 'kaliningrad', 'name': 'Kaliningrad St...
# 45      {'key': 'mordovia', 'name': 'Mordovia Arena'}
# 46    {'key': 'volgograd', 'name': 'Volgograd Arena'}
# 47          {'key': 'samara', 'name': 'Samara Arena'}
# 48          {'key': 'fisht', 'name': 'Fisht Stadium'}
# 49            {'key': 'kazan', 'name': 'Kazan Arena'}
# 50    {'key': 'luzhniki', 'name': 'Luzhniki Stadium'}
# 51  {'key': 'nizhnynovgorod', 'name': 'Nizhny Novg...
# 52          {'key': 'samara', 'name': 'Samara Arena'}
# 53          {'key': 'rostov', 'name': 'Rostov Arena'}
# 54  {'key': 'saintpetersburg', 'name': 'Saint Pete...
# 55      {'key': 'spartak', 'name': 'Spartak Stadium'}
# 56  {'key': 'nizhnynovgorod', 'name': 'Nizhny Novg...
# 57            {'key': 'kazan', 'name': 'Kazan Arena'}
# 58          {'key': 'fisht', 'name': 'Fisht Stadium'}
# 59          {'key': 'samara', 'name': 'Samara Arena'}
# 60  {'key': 'saintpetersburg', 'name': 'Saint Pete...
# 61    {'key': 'luzhniki', 'name': 'Luzhniki Stadium'}
# 62  {'key': 'saintpetersburg', 'name': 'Saint Pete...
# 63    {'key': 'luzhniki', 'name': 'Luzhniki Stadium'}
#
#                                      team1  \
# 0        {'name': 'Russia', 'code': 'RUS'}
# 1         {'name': 'Egypt', 'code': 'EGY'}
# 2      {'name': 'Portugal', 'code': 'POR'}
# 3       {'name': 'Morocco', 'code': 'MAR'}
# 4        {'name': 'France', 'code': 'FRA'}
# 5          {'name': 'Peru', 'code': 'PER'}
# 6     {'name': 'Argentina', 'code': 'ARG'}
# 7       {'name': 'Croatia', 'code': 'CRO'}
# 8        {'name': 'Brazil', 'code': 'BRA'}
# 9    {'name': 'Costa Rica', 'code': 'CRC'}
# 10      {'name': 'Germany', 'code': 'GER'}
# 11       {'name': 'Sweden', 'code': 'SWE'}
# 12      {'name': 'Belgium', 'code': 'BEL'}
# 13      {'name': 'Tunisia', 'code': 'TUN'}
# 14       {'name': 'Poland', 'code': 'POL'}
# 15     {'name': 'Colombia', 'code': 'COL'}
# 16       {'name': 'Russia', 'code': 'RUS'}
# 17      {'name': 'Uruguay', 'code': 'URU'}
# 18     {'name': 'Portugal', 'code': 'POR'}
# 19         {'name': 'Iran', 'code': 'IRN'}
# 20       {'name': 'France', 'code': 'FRA'}
# 21      {'name': 'Denmark', 'code': 'DEN'}
# 22    {'name': 'Argentina', 'code': 'ARG'}
# 23      {'name': 'Nigeria', 'code': 'NGA'}
# 24       {'name': 'Brazil', 'code': 'BRA'}
# 25       {'name': 'Serbia', 'code': 'SRB'}
# 26      {'name': 'Germany', 'code': 'GER'}
# 27  {'name': 'South Korea', 'code': 'KOR'}
# 28      {'name': 'Belgium', 'code': 'BEL'}
# 29      {'name': 'England', 'code': 'ENG'}
# ..                                     ...
# 34         {'name': 'Iran', 'code': 'IRN'}
# 35        {'name': 'Spain', 'code': 'ESP'}
# 36      {'name': 'Denmark', 'code': 'DEN'}
# 37    {'name': 'Australia', 'code': 'AUS'}
# 38      {'name': 'Nigeria', 'code': 'NGA'}
# 39      {'name': 'Iceland', 'code': 'ISL'}
# 40       {'name': 'Serbia', 'code': 'SRB'}
# 41  {'name': 'Switzerland', 'code': 'SUI'}
# 42  {'name': 'South Korea', 'code': 'KOR'}
# 43       {'name': 'Mexico', 'code': 'MEX'}
# 44      {'name': 'England', 'code': 'ENG'}
# 45       {'name': 'Panama', 'code': 'PAN'}
# 46        {'name': 'Japan', 'code': 'JPN'}
# 47      {'name': 'Senegal', 'code': 'SEN'}
# 48      {'name': 'Uruguay', 'code': 'URU'}
# 49       {'name': 'France', 'code': 'FRA'}
# 50        {'name': 'Spain', 'code': 'ESP'}
# 51      {'name': 'Croatia', 'code': 'CRO'}
# 52       {'name': 'Brazil', 'code': 'BRA'}
# 53      {'name': 'Belgium', 'code': 'BEL'}
# 54       {'name': 'Sweden', 'code': 'SWE'}
# 55     {'name': 'Colombia', 'code': 'COL'}
# 56      {'name': 'Uruguay', 'code': 'URU'}
# 57       {'name': 'Brazil', 'code': 'BRA'}
# 58       {'name': 'Russia', 'code': 'RUS'}
# 59       {'name': 'Sweden', 'code': 'SWE'}
# 60       {'name': 'France', 'code': 'FRA'}
# 61      {'name': 'Croatia', 'code': 'CRO'}
# 62      {'name': 'Belgium', 'code': 'BEL'}
# 63       {'name': 'France', 'code': 'FRA'}
#
#                                       team2   time timezone
# 0   {'name': 'Saudi Arabia', 'code': 'KSA'}  18:00    UTC+3
# 1        {'name': 'Uruguay', 'code': 'URU'}  17:00    UTC+5
# 2          {'name': 'Spain', 'code': 'ESP'}  21:00    UTC+3
# 3           {'name': 'Iran', 'code': 'IRN'}  18:00    UTC+3
# 4      {'name': 'Australia', 'code': 'AUS'}  13:00    UTC+3
# 5        {'name': 'Denmark', 'code': 'DEN'}  19:00    UTC+3
# 6        {'name': 'Iceland', 'code': 'ISL'}  16:00    UTC+3
# 7        {'name': 'Nigeria', 'code': 'NGA'}  21:00    UTC+2
# 8    {'name': 'Switzerland', 'code': 'SUI'}  21:00    UTC+3
# 9         {'name': 'Serbia', 'code': 'SRB'}  16:00    UTC+4
# 10        {'name': 'Mexico', 'code': 'MEX'}  18:00    UTC+3
# 11   {'name': 'South Korea', 'code': 'KOR'}  15:00    UTC+3
# 12        {'name': 'Panama', 'code': 'PAN'}  18:00    UTC+3
# 13       {'name': 'England', 'code': 'ENG'}  21:00    UTC+3
# 14       {'name': 'Senegal', 'code': 'SEN'}  18:00    UTC+3
# 15         {'name': 'Japan', 'code': 'JPN'}  15:00    UTC+3
# 16         {'name': 'Egypt', 'code': 'EGY'}  21:00    UTC+3
# 17  {'name': 'Saudi Arabia', 'code': 'KSA'}  18:00    UTC+3
# 18       {'name': 'Morocco', 'code': 'MAR'}  15:00    UTC+3
# 19         {'name': 'Spain', 'code': 'ESP'}  21:00    UTC+3
# 20          {'name': 'Peru', 'code': 'PER'}  20:00    UTC+5
# 21     {'name': 'Australia', 'code': 'AUS'}  16:00    UTC+4
# 22       {'name': 'Croatia', 'code': 'CRO'}  21:00    UTC+3
# 23       {'name': 'Iceland', 'code': 'ISL'}  18:00    UTC+3
# 24    {'name': 'Costa Rica', 'code': 'CRC'}  15:00    UTC+3
# 25   {'name': 'Switzerland', 'code': 'SUI'}  20:00    UTC+2
# 26        {'name': 'Sweden', 'code': 'SWE'}  21:00    UTC+3
# 27        {'name': 'Mexico', 'code': 'MEX'}  18:00    UTC+3
# 28       {'name': 'Tunisia', 'code': 'TUN'}  15:00    UTC+3
# 29        {'name': 'Panama', 'code': 'PAN'}  15:00    UTC+3
# ..                                      ...    ...      ...
# 34      {'name': 'Portugal', 'code': 'POR'}  21:00    UTC+3
# 35       {'name': 'Morocco', 'code': 'MAR'}  20:00    UTC+2
# 36        {'name': 'France', 'code': 'FRA'}  17:00    UTC+3
# 37          {'name': 'Peru', 'code': 'PER'}  17:00    UTC+3
# 38     {'name': 'Argentina', 'code': 'ARG'}  21:00    UTC+3
# 39       {'name': 'Croatia', 'code': 'CRO'}  21:00    UTC+3
# 40        {'name': 'Brazil', 'code': 'BRA'}  21:00    UTC+3
# 41    {'name': 'Costa Rica', 'code': 'CRC'}  21:00    UTC+3
# 42       {'name': 'Germany', 'code': 'GER'}  17:00    UTC+3
# 43        {'name': 'Sweden', 'code': 'SWE'}  19:00    UTC+5
# 44       {'name': 'Belgium', 'code': 'BEL'}  20:00    UTC+2
# 45       {'name': 'Tunisia', 'code': 'TUN'}  21:00    UTC+3
# 46        {'name': 'Poland', 'code': 'POL'}  17:00    UTC+3
# 47      {'name': 'Colombia', 'code': 'COL'}  18:00    UTC+4
# 48      {'name': 'Portugal', 'code': 'POR'}  21:00    UTC+3
# 49     {'name': 'Argentina', 'code': 'ARG'}  17:00    UTC+3
# 50        {'name': 'Russia', 'code': 'RUS'}  17:00    UTC+3
# 51       {'name': 'Denmark', 'code': 'DEN'}  21:00    UTC+3
# 52        {'name': 'Mexico', 'code': 'MEX'}  18:00    UTC+4
# 53         {'name': 'Japan', 'code': 'JPN'}  21:00    UTC+3
# 54   {'name': 'Switzerland', 'code': 'SUI'}  17:00    UTC+3
# 55       {'name': 'England', 'code': 'ENG'}  21:00    UTC+3
# 56        {'name': 'France', 'code': 'FRA'}  17:00    UTC+3
# 57       {'name': 'Belgium', 'code': 'BEL'}  21:00    UTC+3
# 58       {'name': 'Croatia', 'code': 'CRO'}  21:00    UTC+3
# 59       {'name': 'England', 'code': 'ENG'}  18:00    UTC+4
# 60       {'name': 'Belgium', 'code': 'BEL'}  21:00    UTC+3
# 61       {'name': 'England', 'code': 'ENG'}  21:00    UTC+3
# 62       {'name': 'England', 'code': 'ENG'}  17:00    UTC+3
# 63       {'name': 'Croatia', 'code': 'CRO'}  18:00    UTC+3
#
# [64 rows x 20 columns]

# %%
games_df[games_df['goals1'].isnull() == True]
# Out:
#                 city        date goals1 goals2    group knockout  num  score1  \
# 24  Saint Petersburg  2018-06-22    NaN    NaN  Group E      NaN   25       2
# 36            Moscow  2018-06-26    NaN    NaN  Group C      NaN   37       0
#
#     score1et  score1i  score1p  score2  score2et  score2i  score2p  \
# 24       NaN        0      NaN       0       NaN        0      NaN
# 36       NaN        0      NaN       0       NaN        0      NaN
#
#                                               stadium  \
# 24  {'key': 'saintpetersburg', 'name': 'Saint Pete...
# 36    {'key': 'luzhniki', 'name': 'Luzhniki Stadium'}
#
#                                  team1                                  team2  \
# 24   {'name': 'Brazil', 'code': 'BRA'}  {'name': 'Costa Rica', 'code': 'CRC'}
# 36  {'name': 'Denmark', 'code': 'DEN'}      {'name': 'France', 'code': 'FRA'}
#
#      time timezone
# 24  15:00    UTC+3
# 36  17:00    UTC+3

# %%
games_df.at[24, 'goals1'] = [{'name': 'Coutinho', 'minute': 90, 'offset': 1, 'score1': 1, 'score2': 0}, 
                                                {'name': 'Neymar', 'minute': 90, 'offset': 7, 'score1': 2, 'score2': 0}]
games_df.at[24, 'goals2'] = []
games_df[games_df['num'] == 25]
# Out:
#                 city        date  \
# 24  Saint Petersburg  2018-06-22
#
#                                                goals1 goals2    group  \
# 24  [{'name': 'Coutinho', 'minute': 90, 'offset': ...     []  Group E
#
#    knockout  num  score1  score1et  score1i  score1p  score2  score2et  \
# 24      NaN   25       2       NaN        0      NaN       0       NaN
#
#     score2i  score2p                                            stadium  \
# 24        0      NaN  {'key': 'saintpetersburg', 'name': 'Saint Pete...
#
#                                 team1                                  team2  \
# 24  {'name': 'Brazil', 'code': 'BRA'}  {'name': 'Costa Rica', 'code': 'CRC'}
#
#      time timezone
# 24  15:00    UTC+3

# %%
games_df.at[36, 'goals1'] = []
games_df.at[36, 'goals2'] = []
games_df[games_df['num'] == 36]
# Out:
#            city        date  \
# 35  Kaliningrad  2018-06-25
#
#                                                goals1  \
# 35  [{'name': 'Isco', 'minute': 19, 'score1': 1, '...
#
#                                                goals2    group knockout  num  \
# 35  [{'name': 'Boutaib', 'minute': 14, 'score1': 0...  Group B      NaN   36
#
#     score1  score1et  score1i  score1p  score2  score2et  score2i  score2p  \
# 35       2       NaN        1      NaN       2       NaN        1      NaN
#
#                                               stadium  \
# 35  {'key': 'kaliningrad', 'name': 'Kaliningrad St...
#
#                                team1                               team2  \
# 35  {'name': 'Spain', 'code': 'ESP'}  {'name': 'Morocco', 'code': 'MAR'}
#
#      time timezone
# 35  20:00    UTC+2

# %%
print(games_df['goals1'][0])

## minute
print('minute:',games_df['goals1'][0][0]['minute'])

## goalscorer
print('scorer:',games_df['goals1'][0][0]['name'])

##
# Out:
# [{'name': 'Gazinsky', 'minute': 12, 'score1': 1, 'score2': 0}, {'name': 'Cheryshev', 'minute': 43, 'score1': 2, 'score2': 0}, {'name': 'Dzyuba', 'minute': 71, 'score1': 3, 'score2': 0}, {'name': 'Cheryshev', 'minute': 90, 'offset': 1, 'score1': 4, 'score2': 0}, {'name': 'Golovin', 'minute': 90, 'offset': 4, 'score1': 5, 'score2': 0}]
# minute: 12
# scorer: Gazinsky

# %% [markdown]
# for each game:
#
# In creating the data frame for goals, relevant features have to be identified:
# - minute of game
# - 1st half
# - 2nd half
# - et1
# - et2
# - goalscorer
# - country
# - opponent
# - 1st half added time
# - 2nd half added time
# - one hot encoding for losing/drawing/winning position
# - knockout game?
# - date
# - stadium
# - penalty?

# %%
goal_features = ['minute','period_scored','scorer','scorer_team','opp_team','1H_added','2H_added','penalty',
           'game_status','knockout','date','stadium', 'owngoal']

# %%
def time_period(minute):
    if minute <= 45:
        return '1H'
    elif minute > 45 & minute <= 90:
        return '2H'
    elif minute > 90 & minute <= 105:
        return 'et1'
    else:
        return 'et2'

# %%
def key_check(key, obj):
    if key in obj.keys():
        return True
    else:
        return False

# %%
def match_status1(goal):
    if goal['score1'] == 0 & goal['score2'] == 0:
        return 'opening'
    elif goal['score1'] - 1 < goal['score2']:
        return 'losing'
    elif goal['score1'] - 1 == goal['score2']:
        return 'drawing'
    elif goal['score1'] - 1 > goal['score2']:
        return 'winning'
    
def match_status2(goal):
    if goal['score1'] == 0 & goal['score2'] == 0:
        return 'opening'
    elif goal['score2'] - 1 < goal['score1']:
        return 'losing'
    elif goal['score2'] - 1 == goal['score1']:
        return 'drawing'
    elif goal['score2'] - 1 > goal['score1']:
        return 'winning'

# %%
all_goals = []

for index, match in games_df.iterrows():
    for goal in match['goals1']:
        goal_obj = dict.fromkeys(goal_features)
        goal_obj['minute'] = goal['minute']
        goal_obj['period_scored'] = time_period(goal_obj['minute'])
        goal_obj['scorer'] = goal['name'].lower()
        goal_obj['scorer_team'] = match['team1']['name']
        goal_obj['opp_team'] = match['team2']['name']
        if key_check('offset', goal) & (goal_obj['period_scored'] == '1H'):
            goal_obj['1H_added'] = goal['offset']
            goal_obj['2H_added'] = 0
        elif key_check('offset', goal) & (goal_obj['period_scored'] == '2H'):
            goal_obj['1H_added'] = 0
            goal_obj['2H_added'] = goal['offset']
        else:
            goal_obj['1H_added'] = 0
            goal_obj['2H_added'] = 0
        if key_check('penalty',goal):
            goal_obj['penalty'] = 1
        else:
            goal_obj['penalty'] = 0
        goal_obj['game_status'] = match_status1(goal)
        if match['knockout'] == True:
            goal_obj['knockout'] = 1
        else:
            goal_obj['knockout'] = 0
        goal_obj['date'] = match['date']
        goal_obj['stadium'] = match['stadium']['name']
        if key_check('owngoal', goal):
            goal_obj['owngoal'] = 1
        else:
            goal_obj['owngoal'] = 0
        all_goals.append(goal_obj)
        
## for opposing team
    for goal in match['goals2']:
        goal_obj = dict.fromkeys(goal_features)
        goal_obj['minute'] = goal['minute']
        goal_obj['period_scored'] = time_period(goal_obj['minute'])
        goal_obj['scorer'] = goal['name'].lower()
        goal_obj['scorer_team'] = match['team2']['name']
        goal_obj['opp_team'] = match['team1']['name']
        if key_check('offset', goal) & (goal_obj['period_scored'] == '1H'):
            goal_obj['1H_added'] = goal['offset']
            goal_obj['2H_added'] = 0
        elif key_check('offset', goal) & (goal_obj['period_scored'] == '2H'):
            goal_obj['1H_added'] = 0
            goal_obj['2H_added'] = goal['offset']
        else:
            goal_obj['1H_added'] = 0
            goal_obj['2H_added'] = 0
        if key_check('penalty',goal):
            goal_obj['penalty'] = 1
        else:
            goal_obj['penalty'] = 0
        goal_obj['game_status'] = match_status2(goal)
        if match['knockout'] == True:
            goal_obj['knockout'] = 1
        else:
            goal_obj['knockout'] = 0
        goal_obj['date'] = match['date']
        goal_obj['stadium'] = match['stadium']['name']
        if key_check('owngoal', goal):
            goal_obj['owngoal'] = 1
        else:
            goal_obj['owngoal'] = 0
        all_goals.append(goal_obj)  

all_goals
# Out:
# [{'1H_added': 0,
#   '2H_added': 0,
#   'date': '2018-06-14',
#   'game_status': 'drawing',
#   'knockout': 0,
#   'minute': 12,
#   'opp_team': 'Saudi Arabia',
#   'owngoal': 0,
#   'penalty': 0,
#   'period_scored': '1H',
#   'scorer': 'gazinsky',
#   'scorer_team': 'Russia',
#   'stadium': 'Luzhniki Stadium'},
#  {'1H_added': 0,
#   '2H_added': 0,
#   'date': '2018-06-14',
#   'game_status': 'winning',
#   'knockout': 0,
#   'minute': 43,
#   'opp_team': 'Saudi Arabia',
#   'owngoal': 0,
#   'penalty': 0,
#   'period_scored': '1H',
#   'scorer': 'cheryshev',
#   'scorer_team': 'Russia',
#   'stadium': 'Luzhniki Stadium'},
#  {'1H_added': 0,
#   '2H_added': 0,
#   'date': '2018-06-14',
#   'game_status': 'winning',
#   'knockout': 0,
#   'minute': 71,
#   'opp_team': 'Saudi Arabia',
#   'owngoal': 0,
#   'penalty': 0,
#   'period_scored': '2H',
#   'scorer': 'dzyuba',
#   'scorer_team': 'Russia',
#   'stadium': 'Luzhniki Stadium'},
#  {'1H_added': 0,
#   '2H_added': 1,
#   'date': '2018-06-14',
#   'game_status': 'winning',
#   'knockout': 0,
#   'minute': 90,
#   'opp_team': 'Saudi Arabia',
#   'owngoal': 0,
#   'penalty': 0,
#   'period_scored': '2H',
#   'scorer': 'cheryshev',
#   'scorer_team': 'Russia',
#   'stadium': 'Luzhniki Stadium'},
#  {'1H_added': 0,
#   '2H_added': 4,
#   'date': '2018-06-14',
#   'game_status': 'winning',
#   'knockout': 0,
#   'minute': 90,
#   'opp_team': 'Saudi Arabia',
#   'owngoal': 0,
#   'penalty': 0,
#   'period_scored': '2H',
#   'scorer': 'golovin',
#   'scorer_team': 'Russia',
#   'stadium': 'Luzhniki Stadium'},
#  {'1H_added': 0,
#   '2H_added': 0,
#   'date': '2018-06-15',
#   'game_status': 'opening',
#   'knockout': 0,
#   'minute': 89,
#   'opp_team': 'Egypt',
#   'owngoal': 0,
#   'penalty': 0,
#   'period_scored': '2H',
#   'scorer': 'giménez',
#   'scorer_team': 'Uruguay',
#   'stadium': 'Ekaterinburg Arena'},
#  {'1H_added': 0,
#   '2H_added': 0,
#   'date': '2018-06-15',
#   'game_status': 'drawing',
#   'knockout': 0,
#   'minute': 4,
#   'opp_team': 'Spain',
#   'owngoal': 0,
#   'penalty': 1,
#   'period_scored': '1H',
#   'scorer': 'ronaldo',
#   'scorer_team': 'Portugal',
#   'stadium': 'Fisht Stadium'},
#  {'1H_added': 0,
#   '2H_added': 0,
#   'date': '2018-06-15',
#   'game_status': 'drawing',
#   'knockout': 0,
#   'minute': 44,
#   'opp_team': 'Spain',
#   'owngoal': 0,
#   'penalty': 0,
#   'period_scored': '1H',
#   'scorer': 'ronaldo',
#   'scorer_team': 'Portugal',
#   'stadium': 'Fisht Stadium'},
#  {'1H_added': 0,
#   '2H_added': 0,
#   'date': '2018-06-15',
#   'game_status': 'losing',
#   'knockout': 0,
#   'minute': 88,
#   'opp_team': 'Spain',
#   'owngoal': 0,
#   'penalty': 0,
#   'period_scored': '2H',
#   'scorer': 'ronaldo',
#   'scorer_team': 'Portugal',
#   'stadium': 'Fisht Stadium'},
#  {'1H_added': 0,
#   '2H_added': 0,
#   'date': '2018-06-15',
#   'game_status': 'losing',
#   'knockout': 0,
#   'minute': 24,
#   'opp_team': 'Portugal',
#   'owngoal': 0,
#   'penalty': 0,
#   'period_scored': '1H',
#   'scorer': 'costa',
#   'scorer_team': 'Spain',
#   'stadium': 'Fisht Stadium'},
#  {'1H_added': 0,
#   '2H_added': 0,
#   'date': '2018-06-15',
#   'game_status': 'losing',
#   'knockout': 0,
#   'minute': 55,
#   'opp_team': 'Portugal',
#   'owngoal': 0,
#   'penalty': 0,
#   'period_scored': '2H',
#   'scorer': 'costa',
#   'scorer_team': 'Spain',
#   'stadium': 'Fisht Stadium'},
#  {'1H_added': 0,
#   '2H_added': 0,
#   'date': '2018-06-15',
#   'game_status': 'drawing',
#   'knockout': 0,
#   'minute': 58,
#   'opp_team': 'Portugal',
#   'owngoal': 0,
#   'penalty': 0,
#   'period_scored': '2H',
#   'scorer': 'nacho',
#   'scorer_team': 'Spain',
#   'stadium': 'Fisht Stadium'},
#  {'1H_added': 0,
#   '2H_added': 5,
#   'date': '2018-06-15',
#   'game_status': 'opening',
#   'knockout': 0,
#   'minute': 90,
#   'opp_team': 'Morocco',
#   'owngoal': 1,
#   'penalty': 0,
#   'period_scored': '2H',
#   'scorer': 'bouhaddouz',
#   'scorer_team': 'Iran',
#   'stadium': 'Saint Petersburg Stadium'},
#  {'1H_added': 0,
#   '2H_added': 0,
#   'date': '2018-06-16',
#   'game_status': 'drawing',
#   'knockout': 0,
#   'minute': 58,
#   'opp_team': 'Australia',
#   'owngoal': 0,
#   'penalty': 1,
#   'period_scored': '2H',
#   'scorer': 'griezmann',
#   'scorer_team': 'France',
#   'stadium': 'Kazan Arena'},
#  {'1H_added': 0,
#   '2H_added': 0,
#   'date': '2018-06-16',
#   'game_status': 'drawing',
#   'knockout': 0,
#   'minute': 81,
#   'opp_team': 'Australia',
#   'owngoal': 1,
#   'penalty': 0,
#   'period_scored': '2H',
#   'scorer': 'behich',
#   'scorer_team': 'France',
#   'stadium': 'Kazan Arena'},
#  {'1H_added': 0,
#   '2H_added': 0,
#   'date': '2018-06-16',
#   'game_status': 'losing',
#   'knockout': 0,
#   'minute': 62,
#   'opp_team': 'France',
#   'owngoal': 0,
#   'penalty': 1,
#   'period_scored': '2H',
#   'scorer': 'jedinak',
#   'scorer_team': 'Australia',
#   'stadium': 'Kazan Arena'},
#  {'1H_added': 0,
#   '2H_added': 0,
#   'date': '2018-06-16',
#   'game_status': 'opening',
#   'knockout': 0,
#   'minute': 59,
#   'opp_team': 'Peru',
#   'owngoal': 0,
#   'penalty': 0,
#   'period_scored': '2H',
#   'scorer': 'poulsen',
#   'scorer_team': 'Denmark',
#   'stadium': 'Mordovia Arena'},
#  {'1H_added': 0,
#   '2H_added': 0,
#   'date': '2018-06-16',
#   'game_status': 'drawing',
#   'knockout': 0,
#   'minute': 19,
#   'opp_team': 'Iceland',
#   'owngoal': 0,
#   'penalty': 0,
#   'period_scored': '1H',
#   'scorer': 'agüero',
#   'scorer_team': 'Argentina',
#   'stadium': 'Spartak Stadium'},
#  {'1H_added': 0,
#   '2H_added': 0,
#   'date': '2018-06-16',
#   'game_status': 'losing',
#   'knockout': 0,
#   'minute': 23,
#   'opp_team': 'Argentina',
#   'owngoal': 0,
#   'penalty': 0,
#   'period_scored': '1H',
#   'scorer': 'finnbogason',
#   'scorer_team': 'Iceland',
#   'stadium': 'Spartak Stadium'},
#  {'1H_added': 0,
#   '2H_added': 0,
#   'date': '2018-06-16',
#   'game_status': 'drawing',
#   'knockout': 0,
#   'minute': 32,
#   'opp_team': 'Nigeria',
#   'owngoal': 1,
#   'penalty': 0,
#   'period_scored': '1H',
#   'scorer': 'etebo',
#   'scorer_team': 'Croatia',
#   'stadium': 'Kaliningrad Stadium'},
#  {'1H_added': 0,
#   '2H_added': 0,
#   'date': '2018-06-16',
#   'game_status': 'winning',
#   'knockout': 0,
#   'minute': 71,
#   'opp_team': 'Nigeria',
#   'owngoal': 0,
#   'penalty': 1,
#   'period_scored': '2H',
#   'scorer': 'modrić',
#   'scorer_team': 'Croatia',
#   'stadium': 'Kaliningrad Stadium'},
#  {'1H_added': 0,
#   '2H_added': 0,
#   'date': '2018-06-17',
#   'game_status': 'drawing',
#   'knockout': 0,
#   'minute': 20,
#   'opp_team': 'Switzerland',
#   'owngoal': 0,
#   'penalty': 0,
#   'period_scored': '1H',
#   'scorer': 'coutinho',
#   'scorer_team': 'Brazil',
#   'stadium': 'Rostov Arena'},
#  {'1H_added': 0,
#   '2H_added': 0,
#   'date': '2018-06-17',
#   'game_status': 'losing',
#   'knockout': 0,
#   'minute': 50,
#   'opp_team': 'Brazil',
#   'owngoal': 0,
#   'penalty': 0,
#   'period_scored': '2H',
#   'scorer': 'zuber',
#   'scorer_team': 'Switzerland',
#   'stadium': 'Rostov Arena'},
#  {'1H_added': 0,
#   '2H_added': 0,
#   'date': '2018-06-17',
#   'game_status': 'opening',
#   'knockout': 0,
#   'minute': 56,
#   'opp_team': 'Costa Rica',
#   'owngoal': 0,
#   'penalty': 0,
#   'period_scored': '2H',
#   'scorer': 'kolarov',
#   'scorer_team': 'Serbia',
#   'stadium': 'Samara Arena'},
#  {'1H_added': 0,
#   '2H_added': 0,
#   'date': '2018-06-17',
#   'game_status': 'opening',
#   'knockout': 0,
#   'minute': 35,
#   'opp_team': 'Germany',
#   'owngoal': 0,
#   'penalty': 0,
#   'period_scored': '1H',
#   'scorer': 'lozano',
#   'scorer_team': 'Mexico',
#   'stadium': 'Luzhniki Stadium'},
#  {'1H_added': 0,
#   '2H_added': 0,
#   'date': '2018-06-18',
#   'game_status': 'drawing',
#   'knockout': 0,
#   'minute': 65,
#   'opp_team': 'South Korea',
#   'owngoal': 0,
#   'penalty': 1,
#   'period_scored': '2H',
#   'scorer': 'granqvist',
#   'scorer_team': 'Sweden',
#   'stadium': 'Nizhny Novgorod Stadium'},
#  {'1H_added': 0,
#   '2H_added': 0,
#   'date': '2018-06-18',
#   'game_status': 'drawing',
#   'knockout': 0,
#   'minute': 47,
#   'opp_team': 'Panama',
#   'owngoal': 0,
#   'penalty': 0,
#   'period_scored': '2H',
#   'scorer': 'mertens',
#   'scorer_team': 'Belgium',
#   'stadium': 'Fisht Stadium'},
#  {'1H_added': 0,
#   '2H_added': 0,
#   'date': '2018-06-18',
#   'game_status': 'winning',
#   'knockout': 0,
#   'minute': 69,
#   'opp_team': 'Panama',
#   'owngoal': 0,
#   'penalty': 0,
#   'period_scored': '2H',
#   'scorer': 'lukaku',
#   'scorer_team': 'Belgium',
#   'stadium': 'Fisht Stadium'},
#  {'1H_added': 0,
#   '2H_added': 0,
#   'date': '2018-06-18',
#   'game_status': 'winning',
#   'knockout': 0,
#   'minute': 75,
#   'opp_team': 'Panama',
#   'owngoal': 0,
#   'penalty': 0,
#   'period_scored': '2H',
#   'scorer': 'lukaku',
#   'scorer_team': 'Belgium',
#   'stadium': 'Fisht Stadium'},
#  {'1H_added': 0,
#   '2H_added': 0,
#   'date': '2018-06-18',
#   'game_status': 'losing',
#   'knockout': 0,
#   'minute': 35,
#   'opp_team': 'England',
#   'owngoal': 0,
#   'penalty': 1,
#   'period_scored': '1H',
#   'scorer': 'sassi',
#   'scorer_team': 'Tunisia',
#   'stadium': 'Volgograd Arena'},
#  {'1H_added': 0,
#   '2H_added': 0,
#   'date': '2018-06-18',
#   'game_status': 'opening',
#   'knockout': 0,
#   'minute': 11,
#   'opp_team': 'Tunisia',
#   'owngoal': 0,
#   'penalty': 0,
#   'period_scored': '1H',
#   'scorer': 'kane',
#   'scorer_team': 'England',
#   'stadium': 'Volgograd Arena'},
#  {'1H_added': 0,
#   '2H_added': 1,
#   'date': '2018-06-18',
#   'game_status': 'drawing',
#   'knockout': 0,
#   'minute': 90,
#   'opp_team': 'Tunisia',
#   'owngoal': 0,
#   'penalty': 0,
#   'period_scored': '2H',
#   'scorer': 'kane',
#   'scorer_team': 'England',
#   'stadium': 'Volgograd Arena'},
#  {'1H_added': 0,
#   '2H_added': 0,
#   'date': '2018-06-19',
#   'game_status': 'losing',
#   'knockout': 0,
#   'minute': 86,
#   'opp_team': 'Senegal',
#   'owngoal': 0,
#   'penalty': 0,
#   'period_scored': '2H',
#   'scorer': 'krychowiak',
#   'scorer_team': 'Poland',
#   'stadium': 'Spartak Stadium'},
#  {'1H_added': 0,
#   '2H_added': 0,
#   'date': '2018-06-19',
#   'game_status': 'opening',
#   'knockout': 0,
#   'minute': 37,
#   'opp_team': 'Poland',
#   'owngoal': 1,
#   'penalty': 0,
#   'period_scored': '1H',
#   'scorer': 'cionek',
#   'scorer_team': 'Senegal',
#   'stadium': 'Spartak Stadium'},
#  {'1H_added': 0,
#   '2H_added': 0,
#   'date': '2018-06-19',
#   'game_status': 'opening',
#   'knockout': 0,
#   'minute': 60,
#   'opp_team': 'Poland',
#   'owngoal': 0,
#   'penalty': 0,
#   'period_scored': '2H',
#   'scorer': 'niang',
#   'scorer_team': 'Senegal',
#   'stadium': 'Spartak Stadium'},
#  {'1H_added': 0,
#   '2H_added': 0,
#   'date': '2018-06-19',
#   'game_status': 'losing',
#   'knockout': 0,
#   'minute': 39,
#   'opp_team': 'Japan',
#   'owngoal': 0,
#   'penalty': 0,
#   'period_scored': '1H',
#   'scorer': 'j. quintero',
#   'scorer_team': 'Colombia',
#   'stadium': 'Mordovia Arena'},
#  {'1H_added': 0,
#   '2H_added': 0,
#   'date': '2018-06-19',
#   'game_status': 'opening',
#   'knockout': 0,
#   'minute': 6,
#   'opp_team': 'Colombia',
#   'owngoal': 0,
#   'penalty': 1,
#   'period_scored': '1H',
#   'scorer': 'kagawa',
#   'scorer_team': 'Japan',
#   'stadium': 'Mordovia Arena'},
#  {'1H_added': 0,
#   '2H_added': 0,
#   'date': '2018-06-19',
#   'game_status': 'drawing',
#   'knockout': 0,
#   'minute': 73,
#   'opp_team': 'Colombia',
#   'owngoal': 0,
#   'penalty': 0,
#   'period_scored': '2H',
#   'scorer': 'osako',
#   'scorer_team': 'Japan',
#   'stadium': 'Mordovia Arena'},
#  {'1H_added': 0,
#   '2H_added': 0,
#   'date': '2018-06-19',
#   'game_status': 'drawing',
#   'knockout': 0,
#   'minute': 47,
#   'opp_team': 'Egypt',
#   'owngoal': 1,
#   'penalty': 0,
#   'period_scored': '2H',
#   'scorer': 'a. fathi',
#   'scorer_team': 'Russia',
#   'stadium': 'Saint Petersburg Stadium'},
#  {'1H_added': 0,
#   '2H_added': 0,
#   'date': '2018-06-19',
#   'game_status': 'winning',
#   'knockout': 0,
#   'minute': 59,
#   'opp_team': 'Egypt',
#   'owngoal': 0,
#   'penalty': 0,
#   'period_scored': '2H',
#   'scorer': 'cheryshev',
#   'scorer_team': 'Russia',
#   'stadium': 'Saint Petersburg Stadium'},
#  {'1H_added': 0,
#   '2H_added': 0,
#   'date': '2018-06-19',
#   'game_status': 'winning',
#   'knockout': 0,
#   'minute': 62,
#   'opp_team': 'Egypt',
#   'owngoal': 0,
#   'penalty': 0,
#   'period_scored': '2H',
#   'scorer': 'dzyuba',
#   'scorer_team': 'Russia',
#   'stadium': 'Saint Petersburg Stadium'},
#  {'1H_added': 0,
#   '2H_added': 0,
#   'date': '2018-06-19',
#   'game_status': 'losing',
#   'knockout': 0,
#   'minute': 73,
#   'opp_team': 'Russia',
#   'owngoal': 0,
#   'penalty': 1,
#   'period_scored': '2H',
#   'scorer': 'm. salah',
#   'scorer_team': 'Egypt',
#   'stadium': 'Saint Petersburg Stadium'},
#  {'1H_added': 0,
#   '2H_added': 0,
#   'date': '2018-06-20',
#   'game_status': 'drawing',
#   'knockout': 0,
#   'minute': 23,
#   'opp_team': 'Saudi Arabia',
#   'owngoal': 0,
#   'penalty': 0,
#   'period_scored': '1H',
#   'scorer': 'l. suárez',
#   'scorer_team': 'Uruguay',
#   'stadium': 'Rostov Arena'},
#  {'1H_added': 0,
#   '2H_added': 0,
#   'date': '2018-06-20',
#   'game_status': 'drawing',
#   'knockout': 0,
#   'minute': 4,
#   'opp_team': 'Morocco',
#   'owngoal': 0,
#   'penalty': 0,
#   'period_scored': '1H',
#   'scorer': 'ronaldo',
#   'scorer_team': 'Portugal',
#   'stadium': 'Luzhniki Stadium'},
#  {'1H_added': 0,
#   '2H_added': 0,
#   'date': '2018-06-20',
#   'game_status': 'opening',
#   'knockout': 0,
#   'minute': 54,
#   'opp_team': 'Iran',
#   'owngoal': 0,
#   'penalty': 0,
#   'period_scored': '2H',
#   'scorer': 'diego costa',
#   'scorer_team': 'Spain',
#   'stadium': 'Kazan Arena'},
#  {'1H_added': 0,
#   '2H_added': 0,
#   'date': '2018-06-21',
#   'game_status': 'drawing',
#   'knockout': 0,
#   'minute': 34,
#   'opp_team': 'Peru',
#   'owngoal': 0,
#   'penalty': 0,
#   'period_scored': '1H',
#   'scorer': 'mbappé',
#   'scorer_team': 'France',
#   'stadium': 'Ekaterinburg Arena'},
#  {'1H_added': 0,
#   '2H_added': 0,
#   'date': '2018-06-21',
#   'game_status': 'drawing',
#   'knockout': 0,
#   'minute': 7,
#   'opp_team': 'Australia',
#   'owngoal': 0,
#   'penalty': 0,
#   'period_scored': '1H',
#   'scorer': 'eriksen',
#   'scorer_team': 'Denmark',
#   'stadium': 'Samara Arena'},
#  {'1H_added': 0,
#   '2H_added': 0,
#   'date': '2018-06-21',
#   'game_status': 'losing',
#   'knockout': 0,
#   'minute': 38,
#   'opp_team': 'Denmark',
#   'owngoal': 0,
#   'penalty': 1,
#   'period_scored': '1H',
#   'scorer': 'jedinak',
#   'scorer_team': 'Australia',
#   'stadium': 'Samara Arena'},
#  {'1H_added': 0,
#   '2H_added': 0,
#   'date': '2018-06-21',
#   'game_status': 'opening',
#   'knockout': 0,
#   'minute': 53,
#   'opp_team': 'Argentina',
#   'owngoal': 0,
#   'penalty': 0,
#   'period_scored': '2H',
#   'scorer': 'rebić',
#   'scorer_team': 'Croatia',
#   'stadium': 'Nizhny Novgorod Stadium'},
#  {'1H_added': 0,
#   '2H_added': 0,
#   'date': '2018-06-21',
#   'game_status': 'opening',
#   'knockout': 0,
#   'minute': 80,
#   'opp_team': 'Argentina',
#   'owngoal': 0,
#   'penalty': 0,
#   'period_scored': '2H',
#   'scorer': 'modrić',
#   'scorer_team': 'Croatia',
#   'stadium': 'Nizhny Novgorod Stadium'},
#  {'1H_added': 0,
#   '2H_added': 1,
#   'date': '2018-06-21',
#   'game_status': 'opening',
#   'knockout': 0,
#   'minute': 90,
#   'opp_team': 'Argentina',
#   'owngoal': 0,
#   'penalty': 0,
#   'period_scored': '2H',
#   'scorer': 'rakitić',
#   'scorer_team': 'Croatia',
#   'stadium': 'Nizhny Novgorod Stadium'},
#  {'1H_added': 0,
#   '2H_added': 0,
#   'date': '2018-06-22',
#   'game_status': 'drawing',
#   'knockout': 0,
#   'minute': 49,
#   'opp_team': 'Iceland',
#   'owngoal': 0,
#   'penalty': 0,
#   'period_scored': '2H',
#   'scorer': 'musa',
#   'scorer_team': 'Nigeria',
#   'stadium': 'Volgograd Arena'},
#  {'1H_added': 0,
#   '2H_added': 0,
#   'date': '2018-06-22',
#   'game_status': 'winning',
#   'knockout': 0,
#   'minute': 75,
#   'opp_team': 'Iceland',
#   'owngoal': 0,
#   'penalty': 0,
#   'period_scored': '2H',
#   'scorer': 'musa',
#   'scorer_team': 'Nigeria',
#   'stadium': 'Volgograd Arena'},
#  {'1H_added': 0,
#   '2H_added': 1,
#   'date': '2018-06-22',
#   'game_status': 'drawing',
#   'knockout': 0,
#   'minute': 90,
#   'opp_team': 'Costa Rica',
#   'owngoal': 0,
#   'penalty': 0,
#   'period_scored': '2H',
#   'scorer': 'coutinho',
#   'scorer_team': 'Brazil',
#   'stadium': 'Saint Petersburg Stadium'},
#  {'1H_added': 0,
#   '2H_added': 7,
#   'date': '2018-06-22',
#   'game_status': 'winning',
#   'knockout': 0,
#   'minute': 90,
#   'opp_team': 'Costa Rica',
#   'owngoal': 0,
#   'penalty': 0,
#   'period_scored': '2H',
#   'scorer': 'neymar',
#   'scorer_team': 'Brazil',
#   'stadium': 'Saint Petersburg Stadium'},
#  {'1H_added': 0,
#   '2H_added': 0,
#   'date': '2018-06-22',
#   'game_status': 'drawing',
#   'knockout': 0,
#   'minute': 5,
#   'opp_team': 'Switzerland',
#   'owngoal': 0,
#   'penalty': 0,
#   'period_scored': '1H',
#   'scorer': 'mitrović',
#   'scorer_team': 'Serbia',
#   'stadium': 'Kaliningrad Stadium'},
#  {'1H_added': 0,
#   '2H_added': 0,
#   'date': '2018-06-22',
#   'game_status': 'losing',
#   'knockout': 0,
#   'minute': 52,
#   'opp_team': 'Serbia',
#   'owngoal': 0,
#   'penalty': 0,
#   'period_scored': '2H',
#   'scorer': 'xhaka',
#   'scorer_team': 'Switzerland',
#   'stadium': 'Kaliningrad Stadium'},
#  {'1H_added': 0,
#   '2H_added': 0,
#   'date': '2018-06-22',
#   'game_status': 'drawing',
#   'knockout': 0,
#   'minute': 90,
#   'opp_team': 'Serbia',
#   'owngoal': 0,
#   'penalty': 0,
#   'period_scored': '2H',
#   'scorer': 'shaqiri',
#   'scorer_team': 'Switzerland',
#   'stadium': 'Kaliningrad Stadium'},
#  {'1H_added': 0,
#   '2H_added': 0,
#   'date': '2018-06-23',
#   'game_status': 'losing',
#   'knockout': 0,
#   'minute': 48,
#   'opp_team': 'Sweden',
#   'owngoal': 0,
#   'penalty': 0,
#   'period_scored': '2H',
#   'scorer': 'reus',
#   'scorer_team': 'Germany',
#   'stadium': 'Fisht Stadium'},
#  {'1H_added': 0,
#   '2H_added': 5,
#   'date': '2018-06-23',
#   'game_status': 'drawing',
#   'knockout': 0,
#   'minute': 90,
#   'opp_team': 'Sweden',
#   'owngoal': 0,
#   'penalty': 0,
#   'period_scored': '2H',
#   'scorer': 'kroos',
#   'scorer_team': 'Germany',
#   'stadium': 'Fisht Stadium'},
#  {'1H_added': 0,
#   '2H_added': 0,
#   'date': '2018-06-23',
#   'game_status': 'opening',
#   'knockout': 0,
#   'minute': 32,
#   'opp_team': 'Germany',
#   'owngoal': 0,
#   'penalty': 0,
#   'period_scored': '1H',
#   'scorer': 'toivonen',
#   'scorer_team': 'Sweden',
#   'stadium': 'Fisht Stadium'},
#  {'1H_added': 0,
#   '2H_added': 3,
#   'date': '2018-06-23',
#   'game_status': 'losing',
#   'knockout': 0,
#   'minute': 90,
#   'opp_team': 'Mexico',
#   'owngoal': 0,
#   'penalty': 0,
#   'period_scored': '2H',
#   'scorer': 'son heung-min',
#   'scorer_team': 'South Korea',
#   'stadium': 'Rostov Arena'},
#  {'1H_added': 0,
#   '2H_added': 0,
#   'date': '2018-06-23',
#   'game_status': 'opening',
#   'knockout': 0,
#   'minute': 26,
#   'opp_team': 'South Korea',
#   'owngoal': 0,
#   'penalty': 1,
#   'period_scored': '1H',
#   'scorer': 'carlos v.',
#   'scorer_team': 'Mexico',
#   'stadium': 'Rostov Arena'},
#  {'1H_added': 0,
#   '2H_added': 0,
#   'date': '2018-06-23',
#   'game_status': 'opening',
#   'knockout': 0,
#   'minute': 66,
#   'opp_team': 'South Korea',
#   'owngoal': 0,
#   'penalty': 0,
#   'period_scored': '2H',
#   'scorer': 'j. hernández',
#   'scorer_team': 'Mexico',
#   'stadium': 'Rostov Arena'},
#  {'1H_added': 0,
#   '2H_added': 0,
#   'date': '2018-06-23',
#   'game_status': 'drawing',
#   'knockout': 0,
#   'minute': 6,
#   'opp_team': 'Tunisia',
#   'owngoal': 0,
#   'penalty': 1,
#   'period_scored': '1H',
#   'scorer': 'e. hazard',
#   'scorer_team': 'Belgium',
#   'stadium': 'Spartak Stadium'},
#  {'1H_added': 0,
#   '2H_added': 0,
#   'date': '2018-06-23',
#   'game_status': 'winning',
#   'knockout': 0,
#   'minute': 16,
#   'opp_team': 'Tunisia',
#   'owngoal': 0,
#   'penalty': 0,
#   'period_scored': '1H',
#   'scorer': 'r. lukaku',
#   'scorer_team': 'Belgium',
#   'stadium': 'Spartak Stadium'},
#  {'1H_added': 3,
#   '2H_added': 0,
#   'date': '2018-06-23',
#   'game_status': 'winning',
#   'knockout': 0,
#   'minute': 45,
#   'opp_team': 'Tunisia',
#   'owngoal': 0,
#   'penalty': 0,
#   'period_scored': '1H',
#   'scorer': 'r. lukaku',
#   'scorer_team': 'Belgium',
#   'stadium': 'Spartak Stadium'},
#  {'1H_added': 0,
#   '2H_added': 0,
#   'date': '2018-06-23',
#   'game_status': 'winning',
#   'knockout': 0,
#   'minute': 51,
#   'opp_team': 'Tunisia',
#   'owngoal': 0,
#   'penalty': 0,
#   'period_scored': '2H',
#   'scorer': 'e. hazard',
#   'scorer_team': 'Belgium',
#   'stadium': 'Spartak Stadium'},
#  {'1H_added': 0,
#   '2H_added': 0,
#   'date': '2018-06-23',
#   'game_status': 'winning',
#   'knockout': 0,
#   'minute': 90,
#   'opp_team': 'Tunisia',
#   'owngoal': 0,
#   'penalty': 0,
#   'period_scored': '2H',
#   'scorer': 'batshuayi',
#   'scorer_team': 'Belgium',
#   'stadium': 'Spartak Stadium'},
#  {'1H_added': 0,
#   '2H_added': 0,
#   'date': '2018-06-23',
#   'game_status': 'losing',
#   'knockout': 0,
#   'minute': 18,
#   'opp_team': 'Belgium',
#   'owngoal': 0,
#   'penalty': 0,
#   'period_scored': '1H',
#   'scorer': 'bronn',
#   'scorer_team': 'Tunisia',
#   'stadium': 'Spartak Stadium'},
#  {'1H_added': 0,
#   '2H_added': 3,
#   'date': '2018-06-23',
#   'game_status': 'losing',
#   'knockout': 0,
#   'minute': 90,
#   'opp_team': 'Belgium',
#   'owngoal': 0,
#   'penalty': 0,
#   'period_scored': '2H',
#   'scorer': 'khazri',
#   'scorer_team': 'Tunisia',
#   'stadium': 'Spartak Stadium'},
#  {'1H_added': 0,
#   '2H_added': 0,
#   'date': '2018-06-24',
#   'game_status': 'drawing',
#   'knockout': 0,
#   'minute': 8,
#   'opp_team': 'Panama',
#   'owngoal': 0,
#   'penalty': 0,
#   'period_scored': '1H',
#   'scorer': 'stones',
#   'scorer_team': 'England',
#   'stadium': 'Nizhny Novgorod Stadium'},
#  {'1H_added': 0,
#   '2H_added': 0,
#   'date': '2018-06-24',
#   'game_status': 'winning',
#   'knockout': 0,
#   'minute': 22,
#   'opp_team': 'Panama',
#   'owngoal': 0,
#   'penalty': 1,
#   'period_scored': '1H',
#   'scorer': 'kane',
#   'scorer_team': 'England',
#   'stadium': 'Nizhny Novgorod Stadium'},
#  {'1H_added': 0,
#   '2H_added': 0,
#   'date': '2018-06-24',
#   'game_status': 'winning',
#   'knockout': 0,
#   'minute': 36,
#   'opp_team': 'Panama',
#   'owngoal': 0,
#   'penalty': 0,
#   'period_scored': '1H',
#   'scorer': 'lingard',
#   'scorer_team': 'England',
#   'stadium': 'Nizhny Novgorod Stadium'},
#  {'1H_added': 0,
#   '2H_added': 0,
#   'date': '2018-06-24',
#   'game_status': 'winning',
#   'knockout': 0,
#   'minute': 40,
#   'opp_team': 'Panama',
#   'owngoal': 0,
#   'penalty': 0,
#   'period_scored': '1H',
#   'scorer': 'stones',
#   'scorer_team': 'England',
#   'stadium': 'Nizhny Novgorod Stadium'},
#  {'1H_added': 1,
#   '2H_added': 0,
#   'date': '2018-06-24',
#   'game_status': 'winning',
#   'knockout': 0,
#   'minute': 45,
#   'opp_team': 'Panama',
#   'owngoal': 0,
#   'penalty': 1,
#   'period_scored': '1H',
#   'scorer': 'kane',
#   'scorer_team': 'England',
#   'stadium': 'Nizhny Novgorod Stadium'},
#  {'1H_added': 0,
#   '2H_added': 0,
#   'date': '2018-06-24',
#   'game_status': 'winning',
#   'knockout': 0,
#   'minute': 62,
#   'opp_team': 'Panama',
#   'owngoal': 0,
#   'penalty': 0,
#   'period_scored': '2H',
#   'scorer': 'kane',
#   'scorer_team': 'England',
#   'stadium': 'Nizhny Novgorod Stadium'},
#  {'1H_added': 0,
#   '2H_added': 0,
#   'date': '2018-06-24',
#   'game_status': 'losing',
#   'knockout': 0,
#   'minute': 78,
#   'opp_team': 'England',
#   'owngoal': 0,
#   'penalty': 0,
#   'period_scored': '2H',
#   'scorer': 'baloy',
#   'scorer_team': 'Panama',
#   'stadium': 'Nizhny Novgorod Stadium'},
#  {'1H_added': 0,
#   '2H_added': 0,
#   'date': '2018-06-24',
#   'game_status': 'opening',
#   'knockout': 0,
#   'minute': 40,
#   'opp_team': 'Poland',
#   'owngoal': 0,
#   'penalty': 0,
#   'period_scored': '1H',
#   'scorer': 'y. mina',
#   'scorer_team': 'Colombia',
#   'stadium': 'Kazan Arena'},
#  {'1H_added': 0,
#   '2H_added': 0,
#   'date': '2018-06-24',
#   'game_status': 'opening',
#   'knockout': 0,
#   'minute': 70,
#   'opp_team': 'Poland',
#   'owngoal': 0,
#   'penalty': 0,
#   'period_scored': '2H',
#   'scorer': 'falcao',
#   'scorer_team': 'Colombia',
#   'stadium': 'Kazan Arena'},
#  {'1H_added': 0,
#   '2H_added': 0,
#   'date': '2018-06-24',
#   'game_status': 'opening',
#   'knockout': 0,
#   'minute': 75,
#   'opp_team': 'Poland',
#   'owngoal': 0,
#   'penalty': 0,
#   'period_scored': '2H',
#   'scorer': 'cuadrado',
#   'scorer_team': 'Colombia',
#   'stadium': 'Kazan Arena'},
#  {'1H_added': 0,
#   '2H_added': 0,
#   'date': '2018-06-24',
#   'game_status': 'losing',
#   'knockout': 0,
#   'minute': 34,
#   'opp_team': 'Senegal',
#   'owngoal': 0,
#   'penalty': 0,
#   'period_scored': '1H',
#   'scorer': 'inui',
#   'scorer_team': 'Japan',
#   'stadium': 'Ekaterinburg Arena'},
#  {'1H_added': 0,
#   '2H_added': 0,
#   'date': '2018-06-24',
#   'game_status': 'losing',
#   'knockout': 0,
#   'minute': 78,
#   'opp_team': 'Senegal',
#   'owngoal': 0,
#   'penalty': 0,
#   'period_scored': '2H',
#   'scorer': 'honda',
#   'scorer_team': 'Japan',
#   'stadium': 'Ekaterinburg Arena'},
#  {'1H_added': 0,
#   '2H_added': 0,
#   'date': '2018-06-24',
#   'game_status': 'opening',
#   'knockout': 0,
#   'minute': 11,
#   'opp_team': 'Japan',
#   'owngoal': 0,
#   'penalty': 0,
#   'period_scored': '1H',
#   'scorer': 'mané',
#   'scorer_team': 'Senegal',
#   'stadium': 'Ekaterinburg Arena'},
#  {'1H_added': 0,
#   '2H_added': 0,
#   'date': '2018-06-24',
#   'game_status': 'drawing',
#   'knockout': 0,
#   'minute': 71,
#   'opp_team': 'Japan',
#   'owngoal': 0,
#   'penalty': 0,
#   'period_scored': '2H',
#   'scorer': 'm. wagué',
#   'scorer_team': 'Senegal',
#   'stadium': 'Ekaterinburg Arena'},
#  {'1H_added': 0,
#   '2H_added': 0,
#   'date': '2018-06-25',
#   'game_status': 'drawing',
#   'knockout': 0,
#   'minute': 10,
#   'opp_team': 'Russia',
#   'owngoal': 0,
#   'penalty': 0,
#   'period_scored': '1H',
#   'scorer': 'l. suárez',
#   'scorer_team': 'Uruguay',
#   'stadium': 'Samara Arena'},
#  {'1H_added': 0,
#   '2H_added': 0,
#   'date': '2018-06-25',
#   'game_status': 'winning',
#   'knockout': 0,
#   'minute': 23,
#   'opp_team': 'Russia',
#   'owngoal': 1,
#   'penalty': 0,
#   'period_scored': '1H',
#   'scorer': 'cheryshev',
#   'scorer_team': 'Uruguay',
#   'stadium': 'Samara Arena'},
#  {'1H_added': 0,
#   '2H_added': 0,
#   'date': '2018-06-25',
#   'game_status': 'winning',
#   'knockout': 0,
#   'minute': 90,
#   'opp_team': 'Russia',
#   'owngoal': 0,
#   'penalty': 0,
#   'period_scored': '2H',
#   'scorer': 'e. cavani',
#   'scorer_team': 'Uruguay',
#   'stadium': 'Samara Arena'},
#  {'1H_added': 6,
#   '2H_added': 0,
#   'date': '2018-06-25',
#   'game_status': 'losing',
#   'knockout': 0,
#   'minute': 45,
#   'opp_team': 'Egypt',
#   'owngoal': 0,
#   'penalty': 1,
#   'period_scored': '1H',
#   'scorer': 'salman al-faraj',
#   'scorer_team': 'Saudi Arabia',
#   'stadium': 'Volgograd Arena'},
#  {'1H_added': 0,
#   '2H_added': 5,
#   'date': '2018-06-25',
#   'game_status': 'drawing',
#   'knockout': 0,
#   'minute': 90,
#   'opp_team': 'Egypt',
#   'owngoal': 0,
#   'penalty': 0,
#   'period_scored': '2H',
#   'scorer': 'salem al-dawsari',
#   'scorer_team': 'Saudi Arabia',
#   'stadium': 'Volgograd Arena'},
#  {'1H_added': 0,
#   '2H_added': 0,
#   'date': '2018-06-25',
#   'game_status': 'opening',
#   'knockout': 0,
#   'minute': 22,
#   'opp_team': 'Saudi Arabia',
#   'owngoal': 0,
#   'penalty': 0,
#   'period_scored': '1H',
#   'scorer': 'm. salah',
#   'scorer_team': 'Egypt',
#   'stadium': 'Volgograd Arena'},
#  {'1H_added': 0,
#   '2H_added': 3,
#   'date': '2018-06-25',
#   'game_status': 'losing',
#   'knockout': 0,
#   'minute': 90,
#   'opp_team': 'Portugal',
#   'owngoal': 0,
#   'penalty': 1,
#   'period_scored': '2H',
#   'scorer': 'karim ansarifard',
#   'scorer_team': 'Iran',
#   'stadium': 'Mordovia Arena'},
#  {'1H_added': 0,
#   '2H_added': 0,
#   'date': '2018-06-25',
#   'game_status': 'opening',
#   'knockout': 0,
#   'minute': 45,
#   'opp_team': 'Iran',
#   'owngoal': 0,
#   'penalty': 0,
#   'period_scored': '1H',
#   'scorer': 'quaresma',
#   'scorer_team': 'Portugal',
#   'stadium': 'Mordovia Arena'},
#  {'1H_added': 0,
#   '2H_added': 0,
#   'date': '2018-06-25',
#   'game_status': 'losing',
#   'knockout': 0,
#   'minute': 19,
#   'opp_team': 'Morocco',
#   'owngoal': 0,
#   'penalty': 0,
#   'period_scored': '1H',
#   'scorer': 'isco',
#   'scorer_team': 'Spain',
#   'stadium': 'Kaliningrad Stadium'},
#  {'1H_added': 0,
#   '2H_added': 1,
#   'date': '2018-06-25',
#   'game_status': 'losing',
#   'knockout': 0,
#   'minute': 90,
#   'opp_team': 'Morocco',
#   'owngoal': 0,
#   'penalty': 0,
#   'period_scored': '2H',
#   'scorer': 'iago aspas',
#   'scorer_team': 'Spain',
#   'stadium': 'Kaliningrad Stadium'},
#  {'1H_added': 0,
#   '2H_added': 0,
#   'date': '2018-06-25',
#   'game_status': 'opening',
#   'knockout': 0,
#   'minute': 14,
#   'opp_team': 'Spain',
#   'owngoal': 0,
#   'penalty': 0,
#   'period_scored': '1H',
#   'scorer': 'boutaib',
#   'scorer_team': 'Morocco',
#   'stadium': 'Kaliningrad Stadium'},
#  {'1H_added': 0,
#   '2H_added': 0,
#   'date': '2018-06-25',
#   'game_status': 'drawing',
#   'knockout': 0,
#   'minute': 81,
#   'opp_team': 'Spain',
#   'owngoal': 0,
#   'penalty': 0,
#   'period_scored': '2H',
#   'scorer': 'en-nesyri',
#   'scorer_team': 'Morocco',
#   'stadium': 'Kaliningrad Stadium'},
#  {'1H_added': 0,
#   '2H_added': 0,
#   'date': '2018-06-26',
#   'game_status': 'opening',
#   'knockout': 0,
#   'minute': 18,
#   'opp_team': 'Australia',
#   'owngoal': 0,
#   'penalty': 0,
#   'period_scored': '1H',
#   'scorer': 'carrillo',
#   'scorer_team': 'Peru',
#   'stadium': 'Fisht Stadium'},
#  {'1H_added': 0,
#   '2H_added': 0,
#   'date': '2018-06-26',
#   'game_status': 'opening',
#   'knockout': 0,
#   'minute': 50,
#   'opp_team': 'Australia',
#   'owngoal': 0,
#   'penalty': 0,
#   'period_scored': '2H',
#   'scorer': 'guerrero',
#   'scorer_team': 'Peru',
#   'stadium': 'Fisht Stadium'},
#  {'1H_added': 0,
#   '2H_added': 0,
#   'date': '2018-06-26',
#   'game_status': 'losing',
#   'knockout': 0,
#   'minute': 51,
#   'opp_team': 'Argentina',
#   'owngoal': 0,
#   'penalty': 1,
#   'period_scored': '2H',
#   'scorer': 'moses',
#   'scorer_team': 'Nigeria',
#   'stadium': 'Saint Petersburg Stadium'},
#  {'1H_added': 0,
#   '2H_added': 0,
#   'date': '2018-06-26',
#   'game_status': 'opening',
#   'knockout': 0,
#   'minute': 14,
#   'opp_team': 'Nigeria',
#   'owngoal': 0,
#   'penalty': 0,
#   'period_scored': '1H',
#   'scorer': 'messi',
#   'scorer_team': 'Argentina',
#   'stadium': 'Saint Petersburg Stadium'},
#  {'1H_added': 0,
#   '2H_added': 0,
#   'date': '2018-06-26',
#   'game_status': 'drawing',
#   'knockout': 0,
#   'minute': 86,
#   'opp_team': 'Nigeria',
#   'owngoal': 0,
#   'penalty': 0,
#   'period_scored': '2H',
#   'scorer': 'marcos rojo',
#   'scorer_team': 'Argentina',
#   'stadium': 'Saint Petersburg Stadium'},
#  {'1H_added': 0,
#   '2H_added': 0,
#   'date': '2018-06-26',
#   'game_status': 'losing',
#   'knockout': 0,
#   'minute': 76,
#   'opp_team': 'Croatia',
#   'owngoal': 0,
#   'penalty': 1,
#   'period_scored': '2H',
#   'scorer': 'g. sigurðsson',
#   'scorer_team': 'Iceland',
#   'stadium': 'Rostov Arena'},
#  {'1H_added': 0,
#   '2H_added': 0,
#   'date': '2018-06-26',
#   'game_status': 'opening',
#   'knockout': 0,
#   'minute': 53,
#   'opp_team': 'Iceland',
#   'owngoal': 0,
#   'penalty': 0,
#   'period_scored': '2H',
#   'scorer': 'badelj',
#   'scorer_team': 'Croatia',
#   'stadium': 'Rostov Arena'},
#  {'1H_added': 0,
#   '2H_added': 0,
#   'date': '2018-06-26',
#   'game_status': 'drawing',
#   'knockout': 0,
#   'minute': 90,
#   'opp_team': 'Iceland',
#   'owngoal': 0,
#   'penalty': 0,
#   'period_scored': '2H',
#   'scorer': 'perišić',
#   'scorer_team': 'Croatia',
#   'stadium': 'Rostov Arena'},
#  {'1H_added': 0,
#   '2H_added': 0,
#   'date': '2018-06-27',
#   'game_status': 'opening',
#   'knockout': 0,
#   'minute': 36,
#   'opp_team': 'Serbia',
#   'owngoal': 0,
#   'penalty': 0,
#   'period_scored': '1H',
#   'scorer': 'paulinho',
#   'scorer_team': 'Brazil',
#   'stadium': 'Spartak Stadium'},
#  {'1H_added': 0,
#   '2H_added': 0,
#   'date': '2018-06-27',
#   'game_status': 'opening',
#   'knockout': 0,
#   'minute': 68,
#   'opp_team': 'Serbia',
#   'owngoal': 0,
#   'penalty': 0,
#   'period_scored': '2H',
#   'scorer': 'thiago silva',
#   'scorer_team': 'Brazil',
#   'stadium': 'Spartak Stadium'},
#  {'1H_added': 0,
#   '2H_added': 0,
#   'date': '2018-06-27',
#   'game_status': 'drawing',
#   'knockout': 0,
#   'minute': 31,
#   'opp_team': 'Costa Rica',
#   'owngoal': 0,
#   'penalty': 0,
#   'period_scored': '1H',
#   'scorer': 'džemaili',
#   'scorer_team': 'Switzerland',
#   'stadium': 'Nizhny Novgorod Stadium'},
#  {'1H_added': 0,
#   '2H_added': 0,
#   'date': '2018-06-27',
#   'game_status': 'drawing',
#   'knockout': 0,
#   'minute': 88,
#   'opp_team': 'Costa Rica',
#   'owngoal': 0,
#   'penalty': 0,
#   'period_scored': '2H',
#   'scorer': 'drmić',
#   'scorer_team': 'Switzerland',
#   'stadium': 'Nizhny Novgorod Stadium'},
#  {'1H_added': 0,
#   '2H_added': 0,
#   'date': '2018-06-27',
#   'game_status': 'losing',
#   'knockout': 0,
#   'minute': 56,
#   'opp_team': 'Switzerland',
#   'owngoal': 0,
#   'penalty': 0,
#   'period_scored': '2H',
#   'scorer': 'waston',
#   'scorer_team': 'Costa Rica',
#   'stadium': 'Nizhny Novgorod Stadium'},
#  {'1H_added': 0,
#   '2H_added': 3,
#   'date': '2018-06-27',
#   'game_status': 'losing',
#   'knockout': 0,
#   'minute': 90,
#   'opp_team': 'Switzerland',
#   'owngoal': 1,
#   'penalty': 0,
#   'period_scored': '2H',
#   'scorer': 'sommer',
#   'scorer_team': 'Costa Rica',
#   'stadium': 'Nizhny Novgorod Stadium'},
#  {'1H_added': 0,
#   '2H_added': 2,
#   'date': '2018-06-27',
#   'game_status': 'drawing',
#   'knockout': 0,
#   'minute': 90,
#   'opp_team': 'Germany',
#   'owngoal': 0,
#   'penalty': 0,
#   'period_scored': '2H',
#   'scorer': 'kim young-gwon',
#   'scorer_team': 'South Korea',
#   'stadium': 'Kazan Arena'},
#  {'1H_added': 0,
#   '2H_added': 6,
#   'date': '2018-06-27',
#   'game_status': 'winning',
#   'knockout': 0,
#   'minute': 90,
#   'opp_team': 'Germany',
#   'owngoal': 0,
#   'penalty': 0,
#   'period_scored': '2H',
#   'scorer': 'son heung-min',
#   'scorer_team': 'South Korea',
#   'stadium': 'Kazan Arena'},
#  {'1H_added': 0,
#   '2H_added': 0,
#   'date': '2018-06-27',
#   'game_status': 'opening',
#   'knockout': 0,
#   'minute': 50,
#   'opp_team': 'Mexico',
#   'owngoal': 0,
#   'penalty': 0,
#   'period_scored': '2H',
#   'scorer': 'augustinsson',
#   'scorer_team': 'Sweden',
#   'stadium': 'Ekaterinburg Arena'},
#  {'1H_added': 0,
#   '2H_added': 0,
#   'date': '2018-06-27',
#   'game_status': 'opening',
#   'knockout': 0,
#   'minute': 62,
#   'opp_team': 'Mexico',
#   'owngoal': 0,
#   'penalty': 1,
#   'period_scored': '2H',
#   'scorer': 'granqvist',
#   'scorer_team': 'Sweden',
#   'stadium': 'Ekaterinburg Arena'},
#  {'1H_added': 0,
#   '2H_added': 0,
#   'date': '2018-06-27',
#   'game_status': 'opening',
#   'knockout': 0,
#   'minute': 74,
#   'opp_team': 'Mexico',
#   'owngoal': 1,
#   'penalty': 0,
#   'period_scored': '2H',
#   'scorer': 'álvarez',
#   'scorer_team': 'Sweden',
#   'stadium': 'Ekaterinburg Arena'},
#  {'1H_added': 0,
#   '2H_added': 0,
#   'date': '2018-06-28',
#   'game_status': 'opening',
#   'knockout': 0,
#   'minute': 51,
#   'opp_team': 'England',
#   'owngoal': 0,
#   'penalty': 0,
#   'period_scored': '2H',
#   'scorer': 'adnan januzaj',
#   'scorer_team': 'Belgium',
#   'stadium': 'Kaliningrad Stadium'},
#  {'1H_added': 0,
#   '2H_added': 0,
#   'date': '2018-06-28',
#   'game_status': 'drawing',
#   'knockout': 0,
#   'minute': 33,
#   'opp_team': 'Tunisia',
#   'owngoal': 1,
#   'penalty': 0,
#   'period_scored': '1H',
#   'scorer': 'yassine meriah',
#   'scorer_team': 'Panama',
#   'stadium': 'Mordovia Arena'},
#  {'1H_added': 0,
#   '2H_added': 0,
#   'date': '2018-06-28',
#   'game_status': 'losing',
#   'knockout': 0,
#   'minute': 51,
#   'opp_team': 'Panama',
#   'owngoal': 0,
#   'penalty': 0,
#   'period_scored': '2H',
#   'scorer': 'fakhereedine ben youssef',
#   'scorer_team': 'Tunisia',
#   'stadium': 'Mordovia Arena'},
#  {'1H_added': 0,
#   '2H_added': 0,
#   'date': '2018-06-28',
#   'game_status': 'drawing',
#   'knockout': 0,
#   'minute': 66,
#   'opp_team': 'Panama',
#   'owngoal': 0,
#   'penalty': 0,
#   'period_scored': '2H',
#   'scorer': 'wahbi khazri',
#   'scorer_team': 'Tunisia',
#   'stadium': 'Mordovia Arena'},
#  {'1H_added': 0,
#   '2H_added': 0,
#   'date': '2018-06-28',
#   'game_status': 'opening',
#   'knockout': 0,
#   'minute': 59,
#   'opp_team': 'Japan',
#   'owngoal': 0,
#   'penalty': 0,
#   'period_scored': '2H',
#   'scorer': 'bednarek',
#   'scorer_team': 'Poland',
#   'stadium': 'Volgograd Arena'},
#  {'1H_added': 0,
#   '2H_added': 0,
#   'date': '2018-06-28',
#   'game_status': 'opening',
#   'knockout': 0,
#   'minute': 74,
#   'opp_team': 'Senegal',
#   'owngoal': 0,
#   'penalty': 0,
#   'period_scored': '2H',
#   'scorer': 'y. mina',
#   'scorer_team': 'Colombia',
#   'stadium': 'Samara Arena'},
#  {'1H_added': 0,
#   '2H_added': 0,
#   'date': '2018-06-30',
#   'game_status': 'drawing',
#   'knockout': 1,
#   'minute': 7,
#   'opp_team': 'Portugal',
#   'owngoal': 0,
#   'penalty': 0,
#   'period_scored': '1H',
#   'scorer': 'edinson cavani',
#   'scorer_team': 'Uruguay',
#   'stadium': 'Fisht Stadium'},
#  {'1H_added': 0,
#   '2H_added': 0,
#   'date': '2018-06-30',
#   'game_status': 'drawing',
#   'knockout': 1,
#   'minute': 62,
#   'opp_team': 'Portugal',
#   'owngoal': 0,
#   'penalty': 0,
#   'period_scored': '2H',
#   'scorer': 'edinson cavani',
#   'scorer_team': 'Uruguay',
#   'stadium': 'Fisht Stadium'},
#  {'1H_added': 0,
#   '2H_added': 0,
#   'date': '2018-06-30',
#   'game_status': 'losing',
#   'knockout': 1,
#   'minute': 55,
#   'opp_team': 'Uruguay',
#   'owngoal': 0,
#   'penalty': 0,
#   'period_scored': '2H',
#   'scorer': 'pepe',
#   'scorer_team': 'Portugal',
#   'stadium': 'Fisht Stadium'},
#  {'1H_added': 0,
#   '2H_added': 0,
#   'date': '2018-06-30',
#   'game_status': 'drawing',
#   'knockout': 1,
#   'minute': 13,
#   'opp_team': 'Argentina',
#   'owngoal': 0,
#   'penalty': 1,
#   'period_scored': '1H',
#   'scorer': 'antoine griezmann',
#   'scorer_team': 'France',
#   'stadium': 'Kazan Arena'},
#  {'1H_added': 0,
#   '2H_added': 0,
#   'date': '2018-06-30',
#   'game_status': 'losing',
#   'knockout': 1,
#   'minute': 57,
#   'opp_team': 'Argentina',
#   'owngoal': 0,
#   'penalty': 0,
#   'period_scored': '2H',
#   'scorer': 'benjamin pavard',
#   'scorer_team': 'France',
#   'stadium': 'Kazan Arena'},
#  {'1H_added': 0,
#   '2H_added': 0,
#   'date': '2018-06-30',
#   'game_status': 'drawing',
#   'knockout': 1,
#   'minute': 64,
#   'opp_team': 'Argentina',
#   'owngoal': 0,
#   'penalty': 0,
#   'period_scored': '2H',
#   'scorer': 'kylian mbappé',
#   'scorer_team': 'France',
#   'stadium': 'Kazan Arena'},
#  {'1H_added': 0,
#   '2H_added': 0,
#   'date': '2018-06-30',
#   'game_status': 'winning',
#   'knockout': 1,
#   'minute': 68,
#   'opp_team': 'Argentina',
#   'owngoal': 0,
#   'penalty': 0,
#   'period_scored': '2H',
#   'scorer': 'kylian mbappé',
#   'scorer_team': 'France',
#   'stadium': 'Kazan Arena'},
#  {'1H_added': 0,
#   '2H_added': 0,
#   'date': '2018-06-30',
#   'game_status': 'losing',
#   'knockout': 1,
#   'minute': 41,
#   'opp_team': 'France',
#   'owngoal': 0,
#   'penalty': 0,
#   'period_scored': '1H',
#   'scorer': 'ángel di maría',
#   'scorer_team': 'Argentina',
#   'stadium': 'Kazan Arena'},
#  {'1H_added': 0,
#   '2H_added': 0,
#   'date': '2018-06-30',
#   'game_status': 'drawing',
#   'knockout': 1,
#   'minute': 48,
#   'opp_team': 'France',
#   'owngoal': 0,
#   'penalty': 0,
#   'period_scored': '2H',
#   'scorer': 'gabriel mercado',
#   'scorer_team': 'Argentina',
#   'stadium': 'Kazan Arena'},
#  {'1H_added': 0,
#   '2H_added': 3,
#   'date': '2018-06-30',
#   'game_status': 'losing',
#   'knockout': 1,
#   'minute': 90,
#   'opp_team': 'France',
#   'owngoal': 0,
#   'penalty': 0,
#   'period_scored': '2H',
#   'scorer': 'sergio agüero',
#   'scorer_team': 'Argentina',
#   'stadium': 'Kazan Arena'},
#  {'1H_added': 0,
#   '2H_added': 0,
#   'date': '2018-07-01',
#   'game_status': 'drawing',
#   'knockout': 1,
#   'minute': 12,
#   'opp_team': 'Russia',
#   'owngoal': 1,
#   'penalty': 0,
#   'period_scored': '1H',
#   'scorer': 'sergei ignashevich',
#   'scorer_team': 'Spain',
#   'stadium': 'Luzhniki Stadium'},
#  {'1H_added': 0,
#   '2H_added': 0,
#   'date': '2018-07-01',
#   'game_status': 'losing',
#   'knockout': 1,
#   'minute': 41,
#   'opp_team': 'Spain',
#   'owngoal': 0,
#   'penalty': 1,
#   'period_scored': '1H',
#   'scorer': 'artem dzyuba',
#   'scorer_team': 'Russia',
#   'stadium': 'Luzhniki Stadium'},
#  {'1H_added': 0,
#   '2H_added': 0,
#   'date': '2018-07-01',
#   'game_status': 'losing',
#   'knockout': 1,
#   'minute': 4,
#   'opp_team': 'Denmark',
#   'owngoal': 0,
#   'penalty': 0,
#   'period_scored': '1H',
#   'scorer': 'mario mandžukić',
#   'scorer_team': 'Croatia',
#   'stadium': 'Nizhny Novgorod Stadium'},
#  {'1H_added': 0,
#   '2H_added': 0,
#   'date': '2018-07-01',
#   'game_status': 'opening',
#   'knockout': 1,
#   'minute': 1,
#   'opp_team': 'Croatia',
#   'owngoal': 0,
#   'penalty': 0,
#   'period_scored': '1H',
#   'scorer': 'mathias jørgensen',
#   'scorer_team': 'Denmark',
#   'stadium': 'Nizhny Novgorod Stadium'},
#  {'1H_added': 0,
#   '2H_added': 0,
#   'date': '2018-07-02',
#   'game_status': 'drawing',
#   'knockout': 1,
#   'minute': 51,
#   'opp_team': 'Mexico',
#   'owngoal': 0,
#   'penalty': 0,
#   'period_scored': '2H',
#   'scorer': 'neymar',
#   'scorer_team': 'Brazil',
#   'stadium': 'Samara Arena'},
#  {'1H_added': 0,
#   '2H_added': 0,
#   'date': '2018-07-02',
#   'game_status': 'winning',
#   'knockout': 1,
#   'minute': 88,
#   'opp_team': 'Mexico',
#   'owngoal': 0,
#   'penalty': 0,
#   'period_scored': '2H',
#   'scorer': 'roberto firmino',
#   'scorer_team': 'Brazil',
#   'stadium': 'Samara Arena'},
#  {'1H_added': 0,
#   '2H_added': 0,
#   'date': '2018-07-02',
#   'game_status': 'losing',
#   'knockout': 1,
#   'minute': 69,
#   'opp_team': 'Japan',
#   'owngoal': 0,
#   'penalty': 0,
#   'period_scored': '2H',
#   'scorer': 'jan vertonghen',
#   'scorer_team': 'Belgium',
#   'stadium': 'Rostov Arena'},
#  {'1H_added': 0,
#   '2H_added': 0,
#   'date': '2018-07-02',
#   'game_status': 'losing',
#   'knockout': 1,
#   'minute': 74,
#   'opp_team': 'Japan',
#   'owngoal': 0,
#   'penalty': 0,
#   'period_scored': '2H',
#   'scorer': 'marouane fellaini',
#   'scorer_team': 'Belgium',
#   'stadium': 'Rostov Arena'},
#  {'1H_added': 0,
#   '2H_added': 4,
#   'date': '2018-07-02',
#   'game_status': 'drawing',
#   'knockout': 1,
#   'minute': 90,
#   'opp_team': 'Japan',
#   'owngoal': 0,
#   'penalty': 0,
#   'period_scored': '2H',
#   'scorer': 'nacer chadli',
#   'scorer_team': 'Belgium',
#   'stadium': 'Rostov Arena'},
#  {'1H_added': 0,
#   '2H_added': 0,
#   'date': '2018-07-02',
#   'game_status': 'opening',
#   'knockout': 1,
#   'minute': 48,
#   'opp_team': 'Belgium',
#   'owngoal': 0,
#   'penalty': 0,
#   'period_scored': '2H',
#   'scorer': 'genki haraguchi',
#   'scorer_team': 'Japan',
#   'stadium': 'Rostov Arena'},
#  {'1H_added': 0,
#   '2H_added': 0,
#   'date': '2018-07-02',
#   'game_status': 'opening',
#   'knockout': 1,
#   'minute': 52,
#   'opp_team': 'Belgium',
#   'owngoal': 0,
#   'penalty': 0,
#   'period_scored': '2H',
#   'scorer': 'takashi inui',
#   'scorer_team': 'Japan',
#   'stadium': 'Rostov Arena'},
#  {'1H_added': 0,
#   '2H_added': 0,
#   'date': '2018-07-03',
#   'game_status': 'drawing',
#   'knockout': 1,
#   'minute': 66,
#   'opp_team': 'Switzerland',
#   'owngoal': 0,
#   'penalty': 0,
#   'period_scored': '2H',
#   'scorer': 'emil forsberg',
#   'scorer_team': 'Sweden',
#   'stadium': 'Saint Petersburg Stadium'},
#  {'1H_added': 0,
#   '2H_added': 3,
#   'date': '2018-07-03',
#   'game_status': 'losing',
#   'knockout': 1,
#   'minute': 90,
#   'opp_team': 'England',
#   'owngoal': 0,
#   'penalty': 0,
#   'period_scored': '2H',
#   'scorer': 'yerry mina',
#   'scorer_team': 'Colombia',
#   'stadium': 'Spartak Stadium'},
#  {'1H_added': 0,
#   '2H_added': 0,
#   'date': '2018-07-03',
#   'game_status': 'opening',
#   'knockout': 1,
#   'minute': 57,
#   'opp_team': 'Colombia',
#   'owngoal': 0,
#   'penalty': 1,
#   'period_scored': '2H',
#   'scorer': 'harry kane',
#   'scorer_team': 'England',
#   'stadium': 'Spartak Stadium'},
#  {'1H_added': 0,
#   '2H_added': 0,
#   'date': '2018-07-06',
#   'game_status': 'opening',
#   'knockout': 1,
#   'minute': 40,
#   'opp_team': 'Uruguay',
#   'owngoal': 0,
#   'penalty': 0,
#   'period_scored': '1H',
#   'scorer': 'raphaël varane',
#   'scorer_team': 'France',
#   'stadium': 'Nizhny Novgorod Stadium'},
#  {'1H_added': 0,
#   '2H_added': 0,
#   'date': '2018-07-06',
#   'game_status': 'opening',
#   'knockout': 1,
#   'minute': 61,
#   'opp_team': 'Uruguay',
#   'owngoal': 0,
#   'penalty': 0,
#   'period_scored': '2H',
#   'scorer': 'antoine griezmann',
#   'scorer_team': 'France',
#   'stadium': 'Nizhny Novgorod Stadium'},
#  {'1H_added': 0,
#   '2H_added': 0,
#   'date': '2018-07-06',
#   'game_status': 'losing',
#   'knockout': 1,
#   'minute': 76,
#   'opp_team': 'Belgium',
#   'owngoal': 0,
#   'penalty': 0,
#   'period_scored': '2H',
#   'scorer': 'renato augusto',
#   'scorer_team': 'Brazil',
#   'stadium': 'Kazan Arena'},
#  {'1H_added': 0,
#   '2H_added': 0,
#   'date': '2018-07-06',
#   'game_status': 'opening',
#   'knockout': 1,
#   'minute': 13,
#   'opp_team': 'Brazil',
#   'owngoal': 1,
#   'penalty': 0,
#   'period_scored': '1H',
#   'scorer': 'fernandinho',
#   'scorer_team': 'Belgium',
#   'stadium': 'Kazan Arena'},
#  {'1H_added': 0,
#   '2H_added': 0,
#   'date': '2018-07-06',
#   'game_status': 'opening',
#   'knockout': 1,
#   'minute': 31,
#   'opp_team': 'Brazil',
#   'owngoal': 0,
#   'penalty': 0,
#   'period_scored': '1H',
#   'scorer': 'kevin de bruyne',
#   'scorer_team': 'Belgium',
#   'stadium': 'Kazan Arena'},
#  {'1H_added': 0,
#   '2H_added': 0,
#   'date': '2018-07-07',
#   'game_status': 'drawing',
#   'knockout': 1,
#   'minute': 31,
#   'opp_team': 'Croatia',
#   'owngoal': 0,
#   'penalty': 0,
#   'period_scored': '1H',
#   'scorer': 'denis cheryshev',
#   'scorer_team': 'Russia',
#   'stadium': 'Fisht Stadium'},
#  {'1H_added': 0,
#   '2H_added': 0,
#   'date': '2018-07-07',
#   'game_status': 'losing',
#   'knockout': 1,
#   'minute': 115,
#   'opp_team': 'Croatia',
#   'owngoal': 0,
#   'penalty': 0,
#   'period_scored': '2H',
#   'scorer': 'mário figueira fernandes',
#   'scorer_team': 'Russia',
#   'stadium': 'Fisht Stadium'},
#  {'1H_added': 0,
#   '2H_added': 0,
#   'date': '2018-07-07',
#   'game_status': 'losing',
#   'knockout': 1,
#   'minute': 39,
#   'opp_team': 'Russia',
#   'owngoal': 0,
#   'penalty': 0,
#   'period_scored': '1H',
#   'scorer': 'andrej kramarić',
#   'scorer_team': 'Croatia',
#   'stadium': 'Fisht Stadium'},
#  {'1H_added': 0,
#   '2H_added': 0,
#   'date': '2018-07-07',
#   'game_status': 'drawing',
#   'knockout': 1,
#   'minute': 100,
#   'opp_team': 'Russia',
#   'owngoal': 0,
#   'penalty': 0,
#   'period_scored': '2H',
#   'scorer': 'domagoj vida',
#   'scorer_team': 'Croatia',
#   'stadium': 'Fisht Stadium'},
#  {'1H_added': 0,
#   '2H_added': 0,
#   'date': '2018-07-07',
#   'game_status': 'opening',
#   'knockout': 1,
#   'minute': 30,
#   'opp_team': 'Sweden',
#   'owngoal': 0,
#   'penalty': 0,
#   'period_scored': '1H',
#   'scorer': 'harry maguire',
#   'scorer_team': 'England',
#   'stadium': 'Samara Arena'},
#  {'1H_added': 0,
#   '2H_added': 0,
#   'date': '2018-07-07',
#   'game_status': 'opening',
#   'knockout': 1,
#   'minute': 58,
#   'opp_team': 'Sweden',
#   'owngoal': 0,
#   'penalty': 0,
#   'period_scored': '2H',
#   'scorer': 'dele alli',
#   'scorer_team': 'England',
#   'stadium': 'Samara Arena'},
#  {'1H_added': 0,
#   '2H_added': 0,
#   'date': '2018-07-10',
#   'game_status': 'drawing',
#   'knockout': 1,
#   'minute': 51,
#   'opp_team': 'Belgium',
#   'owngoal': 0,
#   'penalty': 0,
#   'period_scored': '2H',
#   'scorer': 'samuel umtiti',
#   'scorer_team': 'France',
#   'stadium': 'Saint Petersburg Stadium'},
#  {'1H_added': 0,
#   '2H_added': 0,
#   'date': '2018-07-11',
#   'game_status': 'losing',
#   'knockout': 1,
#   'minute': 68,
#   'opp_team': 'England',
#   'owngoal': 0,
#   'penalty': 0,
#   'period_scored': '2H',
#   'scorer': 'ivan perišić',
#   'scorer_team': 'Croatia',
#   'stadium': 'Luzhniki Stadium'},
#  {'1H_added': 0,
#   '2H_added': 0,
#   'date': '2018-07-11',
#   'game_status': 'drawing',
#   'knockout': 1,
#   'minute': 109,
#   'opp_team': 'England',
#   'owngoal': 0,
#   'penalty': 0,
#   'period_scored': '2H',
#   'scorer': 'mario mandžukić',
#   'scorer_team': 'Croatia',
#   'stadium': 'Luzhniki Stadium'},
#  {'1H_added': 0,
#   '2H_added': 0,
#   'date': '2018-07-11',
#   'game_status': 'opening',
#   'knockout': 1,
#   'minute': 5,
#   'opp_team': 'Croatia',
#   'owngoal': 0,
#   'penalty': 0,
#   'period_scored': '1H',
#   'scorer': 'kieran trippier',
#   'scorer_team': 'England',
#   'stadium': 'Luzhniki Stadium'},
#  {'1H_added': 0,
#   '2H_added': 0,
#   'date': '2018-07-14',
#   'game_status': 'drawing',
#   'knockout': 1,
#   'minute': 4,
#   'opp_team': 'England',
#   'owngoal': 0,
#   'penalty': 0,
#   'period_scored': '1H',
#   'scorer': 'thomas meunier',
#   'scorer_team': 'Belgium',
#   'stadium': 'Saint Petersburg Stadium'},
#  {'1H_added': 0,
#   '2H_added': 0,
#   'date': '2018-07-14',
#   'game_status': 'winning',
#   'knockout': 1,
#   'minute': 82,
#   'opp_team': 'England',
#   'owngoal': 0,
#   'penalty': 0,
#   'period_scored': '2H',
#   'scorer': 'eden hazard',
#   'scorer_team': 'Belgium',
#   'stadium': 'Saint Petersburg Stadium'},
#  {'1H_added': 0,
#   '2H_added': 0,
#   'date': '2018-07-15',
#   'game_status': 'drawing',
#   'knockout': 1,
#   'minute': 18,
#   'opp_team': 'Croatia',
#   'owngoal': 1,
#   'penalty': 0,
#   'period_scored': '1H',
#   'scorer': 'mario mandžukić',
#   'scorer_team': 'France',
#   'stadium': 'Luzhniki Stadium'},
#  {'1H_added': 0,
#   '2H_added': 0,
#   'date': '2018-07-15',
#   'game_status': 'drawing',
#   'knockout': 1,
#   'minute': 38,
#   'opp_team': 'Croatia',
#   'owngoal': 0,
#   'penalty': 1,
#   'period_scored': '1H',
#   'scorer': 'griezmann',
#   'scorer_team': 'France',
#   'stadium': 'Luzhniki Stadium'},
#  {'1H_added': 0,
#   '2H_added': 0,
#   'date': '2018-07-15',
#   'game_status': 'winning',
#   'knockout': 1,
#   'minute': 59,
#   'opp_team': 'Croatia',
#   'owngoal': 0,
#   'penalty': 0,
#   'period_scored': '2H',
#   'scorer': 'pogba',
#   'scorer_team': 'France',
#   'stadium': 'Luzhniki Stadium'},
#  {'1H_added': 0,
#   '2H_added': 0,
#   'date': '2018-07-15',
#   'game_status': 'winning',
#   'knockout': 1,
#   'minute': 65,
#   'opp_team': 'Croatia',
#   'owngoal': 0,
#   'penalty': 0,
#   'period_scored': '2H',
#   'scorer': 'mbappé',
#   'scorer_team': 'France',
#   'stadium': 'Luzhniki Stadium'},
#  {'1H_added': 0,
#   '2H_added': 0,
#   'date': '2018-07-15',
#   'game_status': 'losing',
#   'knockout': 1,
#   'minute': 28,
#   'opp_team': 'France',
#   'owngoal': 0,
#   'penalty': 0,
#   'period_scored': '1H',
#   'scorer': 'perišić',
#   'scorer_team': 'Croatia',
#   'stadium': 'Luzhniki Stadium'},
#  {'1H_added': 0,
#   '2H_added': 0,
#   'date': '2018-07-15',
#   'game_status': 'losing',
#   'knockout': 1,
#   'minute': 69,
#   'opp_team': 'France',
#   'owngoal': 0,
#   'penalty': 0,
#   'period_scored': '2H',
#   'scorer': 'mario mandžukić',
#   'scorer_team': 'Croatia',
#   'stadium': 'Luzhniki Stadium'}]

# %%
goals_df = pd.DataFrame(all_goals)
goals_df.head()
# Out:
#    1H_added  2H_added        date game_status  knockout  minute      opp_team  \
# 0         0         0  2018-06-14     drawing         0      12  Saudi Arabia
# 1         0         0  2018-06-14     winning         0      43  Saudi Arabia
# 2         0         0  2018-06-14     winning         0      71  Saudi Arabia
# 3         0         1  2018-06-14     winning         0      90  Saudi Arabia
# 4         0         4  2018-06-14     winning         0      90  Saudi Arabia
#
#    owngoal  penalty period_scored     scorer scorer_team           stadium
# 0        0        0            1H   gazinsky      Russia  Luzhniki Stadium
# 1        0        0            1H  cheryshev      Russia  Luzhniki Stadium
# 2        0        0            2H     dzyuba      Russia  Luzhniki Stadium
# 3        0        0            2H  cheryshev      Russia  Luzhniki Stadium
# 4        0        0            2H    golovin      Russia  Luzhniki Stadium

# %%
goals_df[goals_df['minute']>90]
# Out:
#      1H_added  2H_added        date game_status  knockout  minute opp_team  \
# 152         0         0  2018-07-07      losing         1     115  Croatia
# 154         0         0  2018-07-07     drawing         1     100   Russia
# 159         0         0  2018-07-11     drawing         1     109  England
#
#      owngoal  penalty period_scored                    scorer scorer_team  \
# 152        0        0            2H  mário figueira fernandes      Russia
# 154        0        0            2H              domagoj vida     Croatia
# 159        0        0            2H           mario mandžukić     Croatia
#
#               stadium
# 152     Fisht Stadium
# 154     Fisht Stadium
# 159  Luzhniki Stadium

# %%
goals_df = pd.merge(goals_df, teams_df, on='scorer_team', how = 'left')
goals_df.head()
# Out:
#    1H_added  2H_added        date game_status  knockout  minute      opp_team  \
# 0         0         0  2018-06-14     drawing         0      12  Saudi Arabia
# 1         0         0  2018-06-14     winning         0      43  Saudi Arabia
# 2         0         0  2018-06-14     winning         0      71  Saudi Arabia
# 3         0         1  2018-06-14     winning         0      90  Saudi Arabia
# 4         0         4  2018-06-14     winning         0      90  Saudi Arabia
#
#    owngoal  penalty period_scored     scorer scorer_team           stadium  \
# 0        0        0            1H   gazinsky      Russia  Luzhniki Stadium
# 1        0        0            1H  cheryshev      Russia  Luzhniki Stadium
# 2        0        0            2H     dzyuba      Russia  Luzhniki Stadium
# 3        0        0            2H  cheryshev      Russia  Luzhniki Stadium
# 4        0        0            2H    golovin      Russia  Luzhniki Stadium
#
#   countrycode continent
# 0         RUS    Europe
# 1         RUS    Europe
# 2         RUS    Europe
# 3         RUS    Europe
# 4         RUS    Europe

# %%
goals_df[goals_df['owngoal'] == 1]['scorer'].unique()
# Out:
# array(['bouhaddouz', 'behich', 'etebo', 'cionek', 'a. fathi', 'cheryshev',
#        'sommer', 'álvarez', 'yassine meriah', 'sergei ignashevich',
#        'fernandinho', 'mario mandžukić'], dtype=object)

# %% [markdown]
# 1. goals by continent
# 2. cumulative goals by date
# 3. goal distribution by time scored
# 4. goal distribution across stadiums
# 5. goal distribution across time periods
# 6. goals scored from winning vs losing positions
# 7. average goals in knockout games and group games
# 8. distribution of penalty, own goals, actual goals
# 9. scorer by height
# 10. scorer by age

# %%
goals_df['date'] = pd.to_datetime(goals_df['date'])
goals_df.dtypes
# Out:
# 1H_added                  int64
# 2H_added                  int64
# date             datetime64[ns]
# game_status              object
# knockout                  int64
# minute                    int64
# opp_team                 object
# owngoal                   int64
# penalty                   int64
# period_scored            object
# scorer                   object
# scorer_team              object
# stadium                  object
# countrycode              object
# continent                object
# dtype: object

# %%
goals_df['period_scored'].unique()
# Out:
# array(['1H', '2H'], dtype=object)

# %%
# goals by continent

# %matplotlib inline
plt.figure(figsize = (12,5))
sb.countplot(goals_df['continent'], order = goals_df['continent'].value_counts().index)
plt.title('Goals Across Continents', fontsize = 16)
plt.xlabel('Continent')
plt.ylabel('Goals Scored')
# Out:
# Text(0,0.5,'Goals Scored')

# %%
# goals by country
plt.figure(figsize=(40,10))
sb.countplot(goals_df['scorer_team'], order = goals_df['scorer_team'].value_counts().index, color = 'Coral')
plt.title('Total Goals By Team', fontsize = 30)
plt.xlabel('Team', fontsize = 20)
plt.ylabel('Total Goals', fontsize = 20)
# Out:
# Text(0,0.5,'Total Goals')

# %%
# average goals by country
games_df['country1'] = games_df['team1'].apply(lambda x : x['name'])
games_df['country2'] = games_df['team2'].apply(lambda x : x['name'])

x = games_df['country1'].value_counts()
y = games_df['country2'].value_counts()

appearances = dict.fromkeys(games_df['country1'].unique())
for country in x.keys():
    appearances[country] = x[country] + y[country]

z = goals_df['scorer_team'].value_counts()
average = dict.fromkeys(games_df['country1'].unique())
for country in x.keys():
    average[country] = z[country]/appearances[country]
    
sorted_average = sorted(average.items(), key=lambda kv: kv[1], reverse = True)

for x in zip(*sorted_average):
    print(x)

countries, avg = zip(*sorted_average)
plt.figure(figsize=(40,10))
sb.barplot(x=list(countries),y=list(avg), color = 'Coral')
plt.title('Average Goals per Game by Team', fontsize = 30)
plt.xlabel('Team', fontsize = 20)
plt.ylabel('Average Goals per Game', fontsize = 20)
# Out:
# ('Belgium', 'Russia', 'France', 'Croatia', 'Spain', 'England', 'Tunisia', 'Brazil', 'Portugal', 'Argentina', 'Colombia', 'Japan', 'Uruguay', 'Senegal', 'Switzerland', 'Sweden', 'Nigeria', 'South Korea', 'Denmark', 'Mexico', 'Egypt', 'Morocco', 'Peru', 'Costa Rica', 'Germany', 'Poland', 'Iran', 'Serbia', 'Saudi Arabia', 'Australia', 'Iceland', 'Panama')
# (2.2857142857142856, 2.2000000000000002, 2.0, 2.0, 1.75, 1.7142857142857142, 1.6666666666666667, 1.6000000000000001, 1.5, 1.5, 1.5, 1.5, 1.3999999999999999, 1.3333333333333333, 1.25, 1.2, 1.0, 1.0, 0.75, 0.75, 0.66666666666666663, 0.66666666666666663, 0.66666666666666663, 0.66666666666666663, 0.66666666666666663, 0.66666666666666663, 0.66666666666666663, 0.66666666666666663, 0.66666666666666663, 0.66666666666666663, 0.66666666666666663, 0.66666666666666663)
# Text(0,0.5,'Average Goals per Game')

# %%
days = list(range(30))
days.pop(0)


# %matplotlib inline

ax = sb.countplot(data=goals_df, x='date', color = 'Coral')
ax.set_xticklabels(days)
plt.ylabel('Goals on Match Day')
plt.xlabel('Match Day')
plt.title('Goals Scored Each Match Day', fontsize = 14)
# Out:
# Text(0.5,1,'Goals Scored Each Match Day')

# %%
date_goals = goals_df['date'].value_counts()
# sb.distplot(goals_df['date'].value_counts(),
#              hist_kws=dict(cumulative=True),
#              kde_kws=dict(cumulative=True))

# print(sorted(date_goals.index))
# for x in zip(*sorted(date_goals.items())):
#     print (x)

date, goals = zip(*sorted(date_goals.items()))

sb.distplot(list(goals), hist_kws=dict(cumulative=True),
             kde_kws=dict(cumulative=True))

print(list(goals))
# Out:
# [5, 8, 8, 4, 7, 10, 3, 6, 7, 13, 14, 12, 8, 11, 6, 10, 4, 7, 3, 5, 6, 1, 3, 2, 6]

# %%
goals_by_date = dict(zip(date, goals))
goals_by_date_df = pd.Series(goals_by_date)
cumsum_date = goals_by_date_df.cumsum()

ax = plt.figure(figsize=(8,5))

sb.pointplot(x = cumsum_date.index, y = cumsum_date, color = 'Coral')
plt.xticks(np.arange(25),days)
plt.title('Total Goals Over Tournament', fontsize = 14)
plt.xlabel('Match Day')
plt.ylabel('Total Goals in Tournament')
# Out:
# Text(0,0.5,'Total Goals in Tournament')

# %%
plt.figure(figsize = (7,7))
ax = sb.countplot(goals_df['knockout'], order = goals_df['knockout'].value_counts().index)

for p, label in zip(ax.patches, goals_df['knockout'].value_counts()):
    ax.annotate(label, (p.get_x()+0.375, p.get_height()+2))

ax.set_xticklabels(['Group Stage','Knockout'])
ax.set_title('Total Goals in Group Stage and Knockout Games', fontsize = 14)
ax.set_xlabel('Type of Game')
ax.set_ylabel('Total Goals')
# Out:
# Text(0,0.5,'Total Goals')

# %%
plt.figure(figsize=(30,7))
ax = sb.countplot(goals_df['stadium'], order = goals_df['stadium'].value_counts().index)
plt.title('Goals Across Stadiums', fontsize = 30)
plt.xlabel('Stadiums', fontsize = 20)
plt.ylabel('Total Goals in Stadium', fontsize = 20)
for p, label in zip(ax.patches, goals_df['stadium'].value_counts()):
    ax.annotate(label, (p.get_x()+0.375, p.get_height()+0.2))

# %%
def get_per(num, total):
    return (str(num) + ' goals, ' + str(int(num/total*100))+'% of total')

# %%
own_goals = goals_df['owngoal'].sum()
penalties = goals_df['penalty'].sum()
total_goals = len(goals_df)
other_goals = total_goals - penalties - own_goals
percent_distribution = [get_per(own_goals, total_goals),get_per(penalties, total_goals),get_per(other_goals, total_goals),get_per(total_goals, total_goals)]
print(percent_distribution)

ax = plt.figure(figsize = (10,7))
ax = sb.barplot(y = [own_goals,penalties,other_goals,total_goals], x=['Own Goal','Penalty','Other','Total'])

for p, label in zip(ax.patches, percent_distribution):
    ax.annotate(label, (p.get_x(), p.get_height()+3))

plt.title('Goal Types', fontsize = 18)
plt.xlabel('Type of Goal')
plt.ylabel('Total Goals of Type')



# for p, label in zip(ax.patches, goals_df['knockout'].value_counts()):
#     ax.annotate(label, (p.get_x()+0.375, p.get_height()+2))
# Out:
# ['12 goals, 7% of total', '22 goals, 13% of total', '135 goals, 79% of total', '169 goals, 100% of total']
# Text(0,0.5,'Total Goals of Type')

# %%
goals_df['stadium'].value_counts()
# Out:
# Fisht Stadium               21
# Kazan Arena                 19
# Nizhny Novgorod Stadium     19
# Luzhniki Stadium            18
# Spartak Stadium             16
# Saint Petersburg Stadium    14
# Rostov Arena                14
# Samara Arena                11
# Kaliningrad Stadium         10
# Ekaterinburg Arena           9
# Mordovia Arena               9
# Volgograd Arena              9
# Name: stadium, dtype: int64

# %%
plt.figure(figsize = (5,5))
ax = sb.countplot(goals_df['game_status'], order = ['opening','losing','drawing','winning'])
custom = [46,43,52,28]
for p, label in zip(ax.patches, custom):
    ax.annotate(label, (p.get_x() + 0.375,p.get_height()+0.3))
plt.title('Goals Scored by Status of Game', fontsize = 14)
plt.xlabel('Game Status')
plt.ylabel('Goals Scored at Game Status')
# Out:
# Text(0,0.5,'Goals Scored at Game Status')

# %%
import requests
url = 'https://www.fifa.com/common/fifa-world-ranking/_ranking_matchpoints_totals.js'
response = requests.get(url)
string = response.text
json_obj = json.loads(string)
rankings_df = pd.DataFrame(json_obj)
rankings_df = rankings_df[['countrycode','points']]

# %%
with_rankings_df = pd.merge(goals_df, rankings_df, on='countrycode', how='left')
with_rankings_df.head()
# Out:
#    1H_added  2H_added       date game_status  knockout  minute      opp_team  \
# 0         0         0 2018-06-14     drawing         0      12  Saudi Arabia
# 1         0         0 2018-06-14     winning         0      43  Saudi Arabia
# 2         0         0 2018-06-14     winning         0      71  Saudi Arabia
# 3         0         1 2018-06-14     winning         0      90  Saudi Arabia
# 4         0         4 2018-06-14     winning         0      90  Saudi Arabia
#
#    owngoal  penalty period_scored     scorer scorer_team           stadium  \
# 0        0        0            1H   gazinsky      Russia  Luzhniki Stadium
# 1        0        0            1H  cheryshev      Russia  Luzhniki Stadium
# 2        0        0            2H     dzyuba      Russia  Luzhniki Stadium
# 3        0        0            2H  cheryshev      Russia  Luzhniki Stadium
# 4        0        0            2H    golovin      Russia  Luzhniki Stadium
#
#   countrycode continent  points
# 0         RUS    Europe   457.0
# 1         RUS    Europe   457.0
# 2         RUS    Europe   457.0
# 3         RUS    Europe   457.0
# 4         RUS    Europe   457.0

# %%
average_df = pd.DataFrame.from_dict(average, orient = 'index')
average_df.columns = ['average_goals']
average_df['scorer_team'] = average_df.index
average_df = pd.merge(average_df, teams_df, on='scorer_team', how='left')
average_df = pd.merge(average_df, rankings_df, on='countrycode', how='left')

# %%
plt.figure(figsize = (20,5))
sb.swarmplot(data = average_df, x='points', y='average_goals', hue = 'continent', marker = 'o', s=10)

# %%
average_df[average_df['points'] < 600]
# Out:
#     average_goals   scorer_team countrycode        continent  points
# 0        2.200000        Russia         RUS           Europe   457.0
# 21       1.000000   South Korea         KOR             Asia   544.0
# 23       1.500000         Japan         JPN             Asia   521.0
# 24       0.666667  Saudi Arabia         KSA      Middle East   465.0
# 30       0.666667        Panama         PAN  Central America   571.0

# %%
average_df[average_df['average_goals'] > 1.5]
# Out:
#     average_goals scorer_team countrycode      continent  points
# 0        2.200000      Russia         RUS         Europe   457.0
# 4        2.000000      France         FRA         Europe  1198.0
# 7        2.000000     Croatia         CRO         Europe   945.0
# 8        1.600000      Brazil         BRA  South America  1431.0
# 12       2.285714     Belgium         BEL         Europe  1298.0
# 13       1.666667     Tunisia         TUN         Africa   910.0
# 22       1.714286     England         ENG         Europe  1051.0
# 25       1.750000       Spain         ESP         Europe  1126.0

# %%
from tabula import read_pdf
players_df = read_pdf('2018_players.pdf', pages = 'all')
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-727-c8c3d09ab0dc> in <module>()
#       1 from tabula import read_pdf
# ----> 2 players_df = read_pdf('2018_players.pdf', pages = 'all')
#
# /Applications/anaconda3/lib/python3.6/site-packages/tabula/wrapper.py in read_pdf(input_path, output_format, encoding, java_options, pandas_options, multiple_tables, **kwargs)
#      85
#      86     try:
# ---> 87         output = subprocess.check_output(args)
#      88
#      89     except FileNotFoundError as e:
#
# /Applications/anaconda3/lib/python3.6/subprocess.py in check_output(timeout, *popenargs, **kwargs)
#     334
#     335     return run(*popenargs, stdout=PIPE, timeout=timeout, check=True,
# --> 336                **kwargs).stdout
#     337
#     338
#
# /Applications/anaconda3/lib/python3.6/subprocess.py in run(input, timeout, check, *popenargs, **kwargs)
#     403     with Popen(*popenargs, **kwargs) as process:
#     404         try:
# --> 405             stdout, stderr = process.communicate(input, timeout=timeout)
#     406         except TimeoutExpired:
#     407             process.kill()
#
# /Applications/anaconda3/lib/python3.6/subprocess.py in communicate(self, input, timeout)
#     828                 self._stdin_write(input)
#     829             elif self.stdout:
# --> 830                 stdout = self.stdout.read()
#     831                 self.stdout.close()
#     832             elif self.stderr:
#
# KeyboardInterrupt:

# %%
new_cols = ['position','shirtname', 'popname','club_country','birth_date','age','height','weight']
# new_cols_df = pd.DataFrame(columns = new_cols).fillna('')
# new_cols_df.head()

players_df = pd.concat([players_df,pd.DataFrame(columns = new_cols)])
players_df.fillna('', inplace = True)
players_df = players_df.drop(players_df[players_df['#'] == '#'].index)
players_df[players_df['Team'] == 'Belgium']

# %%
def return_rest(arr):
    arr.pop(0)
    return ' '.join(arr).lower()

# %%
return_rest(['dd','adD','da'])

# %%
from datetime import datetime, date

players_df['position'] = players_df['Pos. FIFA Popular Name'].apply(lambda x: x.split(' ')[0])
players_df['height'] = players_df['Height Weight'].apply(lambda x: x.split(' ')[0])
players_df['weight'] = players_df['Height Weight'].apply(lambda x: x.split(' ')[1])
players_df['club_country'] = players_df['Club'].apply(lambda x: x.split(' ')[-1].strip('()'))
players_df['shirtname'] = players_df['Birth Date Shirt Name'].apply(lambda x: return_rest(x.split(' ')))
players_df['popname'] = players_df['Pos. FIFA Popular Name'].apply(lambda x: return_rest(x.split(' ')))
players_df['birth_date'] = players_df['Birth Date Shirt Name'].apply(lambda x: datetime.strptime(x.split(' ')[0],'%d.%m.%Y'))
players_df['age'] = players_df['birth_date'].apply(lambda x: int(((datetime.now() - x).days)/365))
players_df = players_df[['Club','Team','age','club_country','shirtname', 'popname','height','position','weight']]
players_df[players_df['Team'] == 'Belgium']

# %%
players_df[players_df['Team'] == 'France']

# %%
def strip_accents(s):
    """
    Sanitarize the given unicode string and remove all special/localized
    characters from it.
 
    Category "Mn" stands for Nonspacing_Mark
    """
    try:
        return ''.join(
            c for c in unicodedata.normalize('NFD', s)
            if unicodedata.category(c) != 'Mn'
        )
    except:
        return s

# %%
# accents
# one or two phrases
# opposite order

# %%
count = 0
for index, goal in goals_df.iterrows():
    if strip_accents(goal['scorer']) not in strip_accents(players_df['shirtname'].unique()) and strip_accents(goal['scorer'] not in players_df['popname'].unique()):
        count += 1
        print(goal['scorer'])
print(count)

# %%
players_df['shirtname'].unique()

# %%
goals_df['scorer'].unique()
